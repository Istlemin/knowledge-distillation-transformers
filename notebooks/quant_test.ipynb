# %%
import torch
import math
from torch import nn

# %%
inp = torch.randint(2,(100,10))
ans = torch.randint(2,(100,))
# Out:
# C:\Users\fredr\AppData\Local\Temp\ipykernel_17360\680672011.py:1: UserWarning: Failed to initialize NumPy: module compiled against API version 0x10 but this version of numpy is 0xf (Triggered internally at  ..\torch\csrc\utils\tensor_numpy.cpp:68.)
#   inp = torch.randint(2,(100,10))

# %%
def twn_quantizer(clamp_val=2.5):
    class TwnQuantizer(torch.autograd.Function):
        @staticmethod
        def forward(ctx, w : torch.Tensor, dim=None):
            if dim is None:
                dim = tuple(range(len(w.shape)))
            if type(dim) is int:
                dim = (dim,)
            ctx.save_for_backward(w)
            n = math.prod((w.shape[d]) for d in dim)

            w = torch.clamp(w,-clamp_val,clamp_val)

            thres = 0.7 * torch.norm(w, p=1, dim=dim) / n
            for d in dim:
                thres = thres.unsqueeze(d)

            b = (w>thres).type(w.dtype) - (w<-thres).type(w.dtype)
            alpha = torch.norm(b*w,p=1,dim=dim)/torch.norm(b,p=1,dim=dim)
            for d in dim:
                alpha = alpha.unsqueeze(d)

            return alpha*b

        @staticmethod
        def backward(ctx, grad_output):
            """
            Approximate the gradient wrt to the full-precision inputs
            using the gradient wrt to the quantized inputs, 
            zeroing out gradient for clamped values.
            """
            w = ctx.saved_tensors
            grad_output *= (-clamp_val < w < clamp_val)
            return grad_output, None
    
    return TwnQuantizer

# %%
def min_max_quantizer(bits=8, clamp_val=2.5):
    class MinMaxQuantizer(torch.autograd.Function):
        @staticmethod
        def forward(ctx, w : torch.Tensor, dim=None):
            if dim is None:
                dim = tuple(range(len(w.shape)))
            if type(dim) is int:
                dim = (dim,)
            ctx.save_for_backward(w)

            w = torch.clamp(w,-clamp_val,clamp_val)
            
            mn = mx = w
            for d in dim:
                mn = torch.min(mn,dim=d).values
                mx = torch.max(mx,dim=d).values
                mn = mn.unsqueeze(d)
                mx = mx.unsqueeze(d)

            round_factor = (2**bits-1)/(mx-mn)
            quant_w = torch.round((w-mn)*round_factor)/round_factor+mn

            return quant_w


        @staticmethod
        def backward(ctx, grad_output):
            """
            Approximate the gradient wrt to the full-precision inputs
            using the gradient wrt to the quantized inputs, 
            zeroing out gradient for clamped values.
            """
            w, = ctx.saved_tensors
            grad_output *= ((-clamp_val < w) & (w < clamp_val))
            return grad_output, None
            
    return MinMaxQuantizer

# %%
class QuantizedLinear(nn.Module):
    def __init__(self, size_in, size_out, quantizer=twn_quantizer(), quantize_input=False):
        super().__init__()
        
        self.layer = nn.Linear(size_in, size_out)
        self.quantizer = quantizer
        self.quantize_input = quantize_input

    def forward(self, input):
        if self.quantize_input:
            input = self.quantizer.apply(input,(-2,-1))
        quant_weight = self.quantizer.apply(self.layer.weight,(0,1))
        output = nn.functional.linear(input, quant_weight, self.layer.bias)

        return output

# %%
print(torch.clamp(torch.tensor(-1.5),-1,1))
quantizer=min_max_quantizer(4)
w = torch.rand((5,5))*2-1
print(w)
quantizer.apply(w)
# Out:
# tensor(-1.)
# tensor([[-0.2520, -0.9986, -0.6978, -0.8116, -0.2498],
#         [-0.4534, -0.1445, -0.1343, -0.8844, -0.2444],
#         [-0.9627,  0.0402, -0.0448, -0.8209,  0.0904],
#         [ 0.7080,  0.5314,  0.0226,  0.9883, -0.2767],
#         [-0.5458, -0.2103,  0.6451, -0.8749, -0.4863]])
# tensor([[-0.2038, -0.9986, -0.7337, -0.8661, -0.2038],
#         [-0.4688, -0.2038, -0.0714, -0.8661, -0.2038],
#         [-0.9986,  0.0611, -0.0714, -0.8661,  0.0611],
#         [ 0.7234,  0.5909,  0.0611,  0.9883, -0.3363],
#         [-0.6012, -0.2038,  0.5909, -0.8661, -0.4688]])

# %%
model = torch.nn.Sequential(
    QuantizedLinear(10,10,quantizer=quantizer,quantize_input=True),
    torch.nn.ReLU(),
    QuantizedLinear(10,1,quantizer=quantizer,quantize_input=True),
    torch.nn.Sigmoid()
)

# %%
optimizer = torch.optim.Adam(model.parameters(),lr=0.001)

for i in range(100000):
    optimizer.zero_grad()
    loss = torch.sum((model(inp.float())[:,0] - (ans))**2)
    loss.backward()
    optimizer.step()

    print(loss)
# Out:
# tensor(25.5288, grad_fn=<SumBackward0>)
# tensor(25.5322, grad_fn=<SumBackward0>)
# tensor(25.5240, grad_fn=<SumBackward0>)
# tensor(25.4190, grad_fn=<SumBackward0>)
# tensor(25.4370, grad_fn=<SumBackward0>)
# tensor(25.3544, grad_fn=<SumBackward0>)
# tensor(25.3307, grad_fn=<SumBackward0>)
# tensor(25.3120, grad_fn=<SumBackward0>)
# tensor(25.2735, grad_fn=<SumBackward0>)
# tensor(25.2706, grad_fn=<SumBackward0>)
# tensor(25.2631, grad_fn=<SumBackward0>)
# tensor(25.2561, grad_fn=<SumBackward0>)
# tensor(25.2178, grad_fn=<SumBackward0>)
# tensor(25.2189, grad_fn=<SumBackward0>)
# tensor(25.1953, grad_fn=<SumBackward0>)
# tensor(25.1175, grad_fn=<SumBackward0>)
# tensor(25.1098, grad_fn=<SumBackward0>)
# tensor(25.1188, grad_fn=<SumBackward0>)
# tensor(25.0960, grad_fn=<SumBackward0>)
# tensor(25.0810, grad_fn=<SumBackward0>)
# tensor(25.0515, grad_fn=<SumBackward0>)
# tensor(25.0411, grad_fn=<SumBackward0>)
# tensor(25.0359, grad_fn=<SumBackward0>)
# tensor(25.0225, grad_fn=<SumBackward0>)
# tensor(24.9977, grad_fn=<SumBackward0>)
# tensor(24.9550, grad_fn=<SumBackward0>)
# tensor(24.9445, grad_fn=<SumBackward0>)
# tensor(24.8279, grad_fn=<SumBackward0>)
# tensor(24.8414, grad_fn=<SumBackward0>)
# tensor(24.8397, grad_fn=<SumBackward0>)
# tensor(24.8258, grad_fn=<SumBackward0>)
# tensor(24.8453, grad_fn=<SumBackward0>)
# tensor(24.8451, grad_fn=<SumBackward0>)
# tensor(24.8091, grad_fn=<SumBackward0>)
# tensor(24.7856, grad_fn=<SumBackward0>)
# tensor(24.7557, grad_fn=<SumBackward0>)
# tensor(24.7310, grad_fn=<SumBackward0>)
# tensor(24.7337, grad_fn=<SumBackward0>)
# tensor(24.7275, grad_fn=<SumBackward0>)
# tensor(24.7009, grad_fn=<SumBackward0>)
# tensor(24.6753, grad_fn=<SumBackward0>)
# tensor(24.6620, grad_fn=<SumBackward0>)
# tensor(24.6671, grad_fn=<SumBackward0>)
# tensor(24.6264, grad_fn=<SumBackward0>)
# tensor(24.6135, grad_fn=<SumBackward0>)
# tensor(24.6098, grad_fn=<SumBackward0>)
# tensor(24.5711, grad_fn=<SumBackward0>)
# tensor(24.5510, grad_fn=<SumBackward0>)
# tensor(24.5181, grad_fn=<SumBackward0>)
# tensor(24.4650, grad_fn=<SumBackward0>)
# tensor(24.4587, grad_fn=<SumBackward0>)
# tensor(24.5052, grad_fn=<SumBackward0>)
# tensor(24.5051, grad_fn=<SumBackward0>)
# tensor(24.4333, grad_fn=<SumBackward0>)
# tensor(24.4491, grad_fn=<SumBackward0>)
# tensor(24.4558, grad_fn=<SumBackward0>)
# tensor(24.4418, grad_fn=<SumBackward0>)
# tensor(24.4410, grad_fn=<SumBackward0>)
# tensor(24.3830, grad_fn=<SumBackward0>)
# tensor(24.3963, grad_fn=<SumBackward0>)
# tensor(24.3829, grad_fn=<SumBackward0>)
# tensor(24.3787, grad_fn=<SumBackward0>)
# tensor(24.3629, grad_fn=<SumBackward0>)
# tensor(24.3555, grad_fn=<SumBackward0>)
# tensor(24.3348, grad_fn=<SumBackward0>)
# tensor(24.3245, grad_fn=<SumBackward0>)
# tensor(24.2863, grad_fn=<SumBackward0>)
# tensor(24.2307, grad_fn=<SumBackward0>)
# tensor(24.2121, grad_fn=<SumBackward0>)
# tensor(24.1796, grad_fn=<SumBackward0>)
# tensor(24.1671, grad_fn=<SumBackward0>)
# tensor(24.1332, grad_fn=<SumBackward0>)
# tensor(24.1024, grad_fn=<SumBackward0>)
# tensor(24.0999, grad_fn=<SumBackward0>)
# tensor(24.0975, grad_fn=<SumBackward0>)
# tensor(24.0951, grad_fn=<SumBackward0>)
# tensor(24.0631, grad_fn=<SumBackward0>)
# tensor(24.0696, grad_fn=<SumBackward0>)
# tensor(23.9960, grad_fn=<SumBackward0>)
# tensor(23.9952, grad_fn=<SumBackward0>)
# tensor(23.9760, grad_fn=<SumBackward0>)
# tensor(23.9662, grad_fn=<SumBackward0>)
# tensor(23.9327, grad_fn=<SumBackward0>)
# tensor(23.9283, grad_fn=<SumBackward0>)
# tensor(23.9286, grad_fn=<SumBackward0>)
# tensor(23.9403, grad_fn=<SumBackward0>)
# tensor(23.9297, grad_fn=<SumBackward0>)
# tensor(23.9259, grad_fn=<SumBackward0>)
# tensor(23.9557, grad_fn=<SumBackward0>)
# tensor(23.9482, grad_fn=<SumBackward0>)
# tensor(23.9511, grad_fn=<SumBackward0>)
# tensor(23.9317, grad_fn=<SumBackward0>)
# tensor(23.9205, grad_fn=<SumBackward0>)
# tensor(23.8759, grad_fn=<SumBackward0>)
# tensor(23.8625, grad_fn=<SumBackward0>)
# tensor(23.8669, grad_fn=<SumBackward0>)
# tensor(23.8668, grad_fn=<SumBackward0>)
# tensor(23.7550, grad_fn=<SumBackward0>)
# tensor(23.7028, grad_fn=<SumBackward0>)
# tensor(23.6873, grad_fn=<SumBackward0>)
# tensor(23.6951, grad_fn=<SumBackward0>)
# tensor(23.6440, grad_fn=<SumBackward0>)
# tensor(23.6361, grad_fn=<SumBackward0>)
# tensor(23.6731, grad_fn=<SumBackward0>)
# tensor(23.6724, grad_fn=<SumBackward0>)
# tensor(23.6707, grad_fn=<SumBackward0>)
# tensor(23.6014, grad_fn=<SumBackward0>)
# tensor(23.5604, grad_fn=<SumBackward0>)
# tensor(23.5525, grad_fn=<SumBackward0>)
# tensor(23.5250, grad_fn=<SumBackward0>)
# tensor(23.5116, grad_fn=<SumBackward0>)
# tensor(23.5064, grad_fn=<SumBackward0>)
# tensor(23.4910, grad_fn=<SumBackward0>)
# tensor(23.4678, grad_fn=<SumBackward0>)
# tensor(23.4694, grad_fn=<SumBackward0>)
# tensor(23.3911, grad_fn=<SumBackward0>)
# tensor(23.3979, grad_fn=<SumBackward0>)
# tensor(23.3937, grad_fn=<SumBackward0>)
# tensor(23.3808, grad_fn=<SumBackward0>)
# tensor(23.2926, grad_fn=<SumBackward0>)
# tensor(23.2839, grad_fn=<SumBackward0>)
# tensor(23.3012, grad_fn=<SumBackward0>)
# tensor(23.2811, grad_fn=<SumBackward0>)
# tensor(23.2570, grad_fn=<SumBackward0>)
# tensor(23.2547, grad_fn=<SumBackward0>)
# tensor(23.2375, grad_fn=<SumBackward0>)
# tensor(23.2427, grad_fn=<SumBackward0>)
# tensor(23.1627, grad_fn=<SumBackward0>)
# tensor(23.1611, grad_fn=<SumBackward0>)
# tensor(23.1446, grad_fn=<SumBackward0>)
# tensor(23.1356, grad_fn=<SumBackward0>)
# tensor(23.1229, grad_fn=<SumBackward0>)
# tensor(23.0801, grad_fn=<SumBackward0>)
# tensor(23.1280, grad_fn=<SumBackward0>)
# tensor(23.1201, grad_fn=<SumBackward0>)
# tensor(23.1020, grad_fn=<SumBackward0>)
# tensor(23.0819, grad_fn=<SumBackward0>)
# tensor(23.0781, grad_fn=<SumBackward0>)
# tensor(23.0018, grad_fn=<SumBackward0>)
# tensor(22.9876, grad_fn=<SumBackward0>)
# tensor(22.9601, grad_fn=<SumBackward0>)
# tensor(22.9650, grad_fn=<SumBackward0>)
# tensor(22.9576, grad_fn=<SumBackward0>)
# tensor(22.9506, grad_fn=<SumBackward0>)
# tensor(22.9421, grad_fn=<SumBackward0>)
# tensor(22.9051, grad_fn=<SumBackward0>)
# tensor(22.8708, grad_fn=<SumBackward0>)
# tensor(22.8637, grad_fn=<SumBackward0>)
# tensor(22.8995, grad_fn=<SumBackward0>)
# tensor(22.8933, grad_fn=<SumBackward0>)
# tensor(22.8680, grad_fn=<SumBackward0>)
# tensor(22.8509, grad_fn=<SumBackward0>)
# tensor(22.8039, grad_fn=<SumBackward0>)
# tensor(22.7738, grad_fn=<SumBackward0>)
# tensor(22.7355, grad_fn=<SumBackward0>)
# tensor(22.7561, grad_fn=<SumBackward0>)
# tensor(22.7506, grad_fn=<SumBackward0>)
# tensor(22.7096, grad_fn=<SumBackward0>)
# tensor(22.7359, grad_fn=<SumBackward0>)
# tensor(22.7405, grad_fn=<SumBackward0>)
# tensor(22.7301, grad_fn=<SumBackward0>)
# tensor(22.6808, grad_fn=<SumBackward0>)
# tensor(22.6777, grad_fn=<SumBackward0>)
# tensor(22.6748, grad_fn=<SumBackward0>)
# tensor(22.6640, grad_fn=<SumBackward0>)
# tensor(22.6225, grad_fn=<SumBackward0>)
# tensor(22.6260, grad_fn=<SumBackward0>)
# tensor(22.6713, grad_fn=<SumBackward0>)
# tensor(22.5841, grad_fn=<SumBackward0>)
# tensor(22.5838, grad_fn=<SumBackward0>)
# tensor(22.5177, grad_fn=<SumBackward0>)
# tensor(22.4940, grad_fn=<SumBackward0>)
# tensor(22.4371, grad_fn=<SumBackward0>)
# tensor(22.3655, grad_fn=<SumBackward0>)
# tensor(22.5331, grad_fn=<SumBackward0>)
# tensor(22.5221, grad_fn=<SumBackward0>)
# tensor(22.4869, grad_fn=<SumBackward0>)
# tensor(22.5222, grad_fn=<SumBackward0>)
# tensor(22.4929, grad_fn=<SumBackward0>)
# tensor(22.4666, grad_fn=<SumBackward0>)
# tensor(22.4604, grad_fn=<SumBackward0>)
# tensor(22.4703, grad_fn=<SumBackward0>)
# tensor(22.4469, grad_fn=<SumBackward0>)
# tensor(22.4342, grad_fn=<SumBackward0>)
# tensor(22.3876, grad_fn=<SumBackward0>)
# tensor(22.3717, grad_fn=<SumBackward0>)
# tensor(22.3445, grad_fn=<SumBackward0>)
# tensor(22.3433, grad_fn=<SumBackward0>)
# tensor(22.2593, grad_fn=<SumBackward0>)
# tensor(22.2505, grad_fn=<SumBackward0>)
# tensor(22.2750, grad_fn=<SumBackward0>)
# tensor(22.2364, grad_fn=<SumBackward0>)
# tensor(22.3008, grad_fn=<SumBackward0>)
# tensor(22.2368, grad_fn=<SumBackward0>)
# tensor(22.1286, grad_fn=<SumBackward0>)
# tensor(22.1201, grad_fn=<SumBackward0>)
# tensor(22.0729, grad_fn=<SumBackward0>)
# tensor(22.0755, grad_fn=<SumBackward0>)
# tensor(22.0492, grad_fn=<SumBackward0>)
# tensor(22.0570, grad_fn=<SumBackward0>)
# tensor(22.0476, grad_fn=<SumBackward0>)
# tensor(21.9809, grad_fn=<SumBackward0>)
# tensor(21.9657, grad_fn=<SumBackward0>)
# tensor(21.9769, grad_fn=<SumBackward0>)
# tensor(21.9461, grad_fn=<SumBackward0>)
# tensor(21.9217, grad_fn=<SumBackward0>)
# tensor(21.9360, grad_fn=<SumBackward0>)
# tensor(21.9430, grad_fn=<SumBackward0>)
# tensor(21.8759, grad_fn=<SumBackward0>)
# tensor(21.8227, grad_fn=<SumBackward0>)
# tensor(21.8480, grad_fn=<SumBackward0>)
# tensor(21.8341, grad_fn=<SumBackward0>)
# tensor(21.8044, grad_fn=<SumBackward0>)
# tensor(21.8066, grad_fn=<SumBackward0>)
# tensor(21.8462, grad_fn=<SumBackward0>)
# tensor(21.9406, grad_fn=<SumBackward0>)
# tensor(21.9581, grad_fn=<SumBackward0>)
# tensor(21.8641, grad_fn=<SumBackward0>)
# tensor(21.8317, grad_fn=<SumBackward0>)
# tensor(21.8300, grad_fn=<SumBackward0>)
# tensor(21.8096, grad_fn=<SumBackward0>)
# tensor(21.7369, grad_fn=<SumBackward0>)
# tensor(21.7582, grad_fn=<SumBackward0>)
# tensor(21.6839, grad_fn=<SumBackward0>)
# tensor(21.6120, grad_fn=<SumBackward0>)
# tensor(21.6555, grad_fn=<SumBackward0>)
# tensor(21.6658, grad_fn=<SumBackward0>)
# tensor(21.5537, grad_fn=<SumBackward0>)
# tensor(21.5657, grad_fn=<SumBackward0>)
# tensor(21.5429, grad_fn=<SumBackward0>)
# tensor(21.4997, grad_fn=<SumBackward0>)
# tensor(21.4715, grad_fn=<SumBackward0>)
# tensor(21.4342, grad_fn=<SumBackward0>)
# tensor(21.4690, grad_fn=<SumBackward0>)
# tensor(21.5031, grad_fn=<SumBackward0>)
# tensor(21.5184, grad_fn=<SumBackward0>)
# tensor(21.4969, grad_fn=<SumBackward0>)
# tensor(21.5068, grad_fn=<SumBackward0>)
# tensor(21.5655, grad_fn=<SumBackward0>)
# tensor(21.5177, grad_fn=<SumBackward0>)
# tensor(21.5488, grad_fn=<SumBackward0>)
# tensor(21.5637, grad_fn=<SumBackward0>)
# tensor(21.5547, grad_fn=<SumBackward0>)
# tensor(21.4941, grad_fn=<SumBackward0>)
# tensor(21.5112, grad_fn=<SumBackward0>)
# tensor(21.4801, grad_fn=<SumBackward0>)
# tensor(21.3851, grad_fn=<SumBackward0>)
# tensor(21.4814, grad_fn=<SumBackward0>)
# tensor(21.4625, grad_fn=<SumBackward0>)
# tensor(21.4518, grad_fn=<SumBackward0>)
# tensor(21.4839, grad_fn=<SumBackward0>)
# tensor(21.4484, grad_fn=<SumBackward0>)
# tensor(21.4411, grad_fn=<SumBackward0>)
# tensor(21.4272, grad_fn=<SumBackward0>)
# tensor(21.3661, grad_fn=<SumBackward0>)
# tensor(21.3348, grad_fn=<SumBackward0>)
# tensor(21.3594, grad_fn=<SumBackward0>)
# tensor(21.3118, grad_fn=<SumBackward0>)
# tensor(21.3004, grad_fn=<SumBackward0>)
# tensor(21.2541, grad_fn=<SumBackward0>)
# tensor(21.2677, grad_fn=<SumBackward0>)
# tensor(21.2321, grad_fn=<SumBackward0>)
# tensor(21.2249, grad_fn=<SumBackward0>)
# tensor(21.2185, grad_fn=<SumBackward0>)
# tensor(21.2362, grad_fn=<SumBackward0>)
# tensor(21.2154, grad_fn=<SumBackward0>)
# tensor(21.2450, grad_fn=<SumBackward0>)
# tensor(21.2432, grad_fn=<SumBackward0>)
# tensor(21.2347, grad_fn=<SumBackward0>)
# tensor(21.2235, grad_fn=<SumBackward0>)
# tensor(21.1662, grad_fn=<SumBackward0>)
# tensor(21.1962, grad_fn=<SumBackward0>)
# tensor(21.2597, grad_fn=<SumBackward0>)
# tensor(21.3531, grad_fn=<SumBackward0>)
# tensor(21.3286, grad_fn=<SumBackward0>)
# tensor(21.1445, grad_fn=<SumBackward0>)
# tensor(21.1107, grad_fn=<SumBackward0>)
# tensor(21.1075, grad_fn=<SumBackward0>)
# tensor(21.0909, grad_fn=<SumBackward0>)
# tensor(21.0590, grad_fn=<SumBackward0>)
# tensor(21.0822, grad_fn=<SumBackward0>)
# tensor(21.0604, grad_fn=<SumBackward0>)
# tensor(21.0592, grad_fn=<SumBackward0>)
# tensor(21.0282, grad_fn=<SumBackward0>)
# tensor(21.1100, grad_fn=<SumBackward0>)
# tensor(21.1707, grad_fn=<SumBackward0>)
# tensor(20.9584, grad_fn=<SumBackward0>)
# tensor(20.8085, grad_fn=<SumBackward0>)
# tensor(20.7721, grad_fn=<SumBackward0>)
# tensor(20.7454, grad_fn=<SumBackward0>)
# tensor(20.8162, grad_fn=<SumBackward0>)
# tensor(20.7887, grad_fn=<SumBackward0>)
# tensor(20.8149, grad_fn=<SumBackward0>)
# tensor(20.8847, grad_fn=<SumBackward0>)
# tensor(20.8799, grad_fn=<SumBackward0>)
# tensor(20.8655, grad_fn=<SumBackward0>)
# tensor(20.8663, grad_fn=<SumBackward0>)
# tensor(20.9378, grad_fn=<SumBackward0>)
# tensor(20.9216, grad_fn=<SumBackward0>)
# tensor(20.8900, grad_fn=<SumBackward0>)
# tensor(20.8902, grad_fn=<SumBackward0>)
# tensor(20.8368, grad_fn=<SumBackward0>)
# tensor(20.8615, grad_fn=<SumBackward0>)
# tensor(20.7631, grad_fn=<SumBackward0>)
# tensor(20.7219, grad_fn=<SumBackward0>)
# tensor(20.7395, grad_fn=<SumBackward0>)
# tensor(20.8051, grad_fn=<SumBackward0>)
# tensor(20.6719, grad_fn=<SumBackward0>)
# tensor(20.5929, grad_fn=<SumBackward0>)
# tensor(20.6847, grad_fn=<SumBackward0>)
# tensor(20.7086, grad_fn=<SumBackward0>)
# tensor(20.7082, grad_fn=<SumBackward0>)
# tensor(20.6740, grad_fn=<SumBackward0>)
# tensor(20.6619, grad_fn=<SumBackward0>)
# tensor(20.6545, grad_fn=<SumBackward0>)
# tensor(20.6509, grad_fn=<SumBackward0>)
# tensor(20.5528, grad_fn=<SumBackward0>)
# tensor(20.5532, grad_fn=<SumBackward0>)
# tensor(20.5226, grad_fn=<SumBackward0>)
# tensor(20.5393, grad_fn=<SumBackward0>)
# tensor(20.5356, grad_fn=<SumBackward0>)
# tensor(20.3804, grad_fn=<SumBackward0>)
# tensor(20.4476, grad_fn=<SumBackward0>)
# tensor(20.4108, grad_fn=<SumBackward0>)
# tensor(20.3870, grad_fn=<SumBackward0>)
# tensor(20.3448, grad_fn=<SumBackward0>)
# tensor(20.3114, grad_fn=<SumBackward0>)
# tensor(20.3278, grad_fn=<SumBackward0>)
# tensor(20.3736, grad_fn=<SumBackward0>)
# tensor(20.4040, grad_fn=<SumBackward0>)
# tensor(20.3160, grad_fn=<SumBackward0>)
# tensor(20.2863, grad_fn=<SumBackward0>)
# tensor(20.2389, grad_fn=<SumBackward0>)
# tensor(20.2807, grad_fn=<SumBackward0>)
# tensor(20.2735, grad_fn=<SumBackward0>)
# tensor(20.2703, grad_fn=<SumBackward0>)
# tensor(20.1920, grad_fn=<SumBackward0>)
# tensor(20.1886, grad_fn=<SumBackward0>)
# tensor(20.1888, grad_fn=<SumBackward0>)
# tensor(20.1891, grad_fn=<SumBackward0>)
# tensor(20.2700, grad_fn=<SumBackward0>)
# tensor(20.2877, grad_fn=<SumBackward0>)
# tensor(20.1835, grad_fn=<SumBackward0>)
# tensor(20.1776, grad_fn=<SumBackward0>)
# tensor(20.2879, grad_fn=<SumBackward0>)
# tensor(20.0467, grad_fn=<SumBackward0>)
# tensor(20.0395, grad_fn=<SumBackward0>)
# tensor(20.0117, grad_fn=<SumBackward0>)
# tensor(19.9873, grad_fn=<SumBackward0>)
# tensor(20.0502, grad_fn=<SumBackward0>)
# tensor(20.2083, grad_fn=<SumBackward0>)
# tensor(20.2187, grad_fn=<SumBackward0>)
# tensor(20.1772, grad_fn=<SumBackward0>)
# tensor(20.1666, grad_fn=<SumBackward0>)
# tensor(20.0004, grad_fn=<SumBackward0>)
# tensor(19.9183, grad_fn=<SumBackward0>)
# tensor(19.9232, grad_fn=<SumBackward0>)
# tensor(19.9565, grad_fn=<SumBackward0>)
# tensor(19.9895, grad_fn=<SumBackward0>)
# tensor(19.9288, grad_fn=<SumBackward0>)
# tensor(19.9832, grad_fn=<SumBackward0>)
# tensor(19.9709, grad_fn=<SumBackward0>)
# tensor(20.0469, grad_fn=<SumBackward0>)
# tensor(20.0317, grad_fn=<SumBackward0>)
# tensor(19.8808, grad_fn=<SumBackward0>)
# tensor(19.8410, grad_fn=<SumBackward0>)
# tensor(19.8457, grad_fn=<SumBackward0>)
# tensor(19.8173, grad_fn=<SumBackward0>)
# tensor(19.8701, grad_fn=<SumBackward0>)
# tensor(19.8953, grad_fn=<SumBackward0>)
# tensor(19.8157, grad_fn=<SumBackward0>)
# tensor(19.7801, grad_fn=<SumBackward0>)
# tensor(19.8207, grad_fn=<SumBackward0>)
# tensor(19.8279, grad_fn=<SumBackward0>)
# tensor(19.8648, grad_fn=<SumBackward0>)
# tensor(19.8716, grad_fn=<SumBackward0>)
# tensor(19.8494, grad_fn=<SumBackward0>)
# tensor(19.8394, grad_fn=<SumBackward0>)
# tensor(19.8218, grad_fn=<SumBackward0>)
# tensor(19.6885, grad_fn=<SumBackward0>)
# tensor(19.5996, grad_fn=<SumBackward0>)
# tensor(19.5588, grad_fn=<SumBackward0>)
# tensor(19.6091, grad_fn=<SumBackward0>)
# tensor(19.6220, grad_fn=<SumBackward0>)
# tensor(19.5900, grad_fn=<SumBackward0>)
# tensor(19.5666, grad_fn=<SumBackward0>)
# tensor(19.5596, grad_fn=<SumBackward0>)
# tensor(19.4672, grad_fn=<SumBackward0>)
# tensor(19.4036, grad_fn=<SumBackward0>)
# tensor(19.4086, grad_fn=<SumBackward0>)
# tensor(19.5764, grad_fn=<SumBackward0>)
# tensor(19.6680, grad_fn=<SumBackward0>)
# tensor(19.5971, grad_fn=<SumBackward0>)
# tensor(19.5821, grad_fn=<SumBackward0>)
# tensor(19.2583, grad_fn=<SumBackward0>)
# tensor(19.3244, grad_fn=<SumBackward0>)
# tensor(19.5388, grad_fn=<SumBackward0>)
# tensor(19.5110, grad_fn=<SumBackward0>)
# tensor(19.4506, grad_fn=<SumBackward0>)
# tensor(19.4622, grad_fn=<SumBackward0>)
# tensor(19.3984, grad_fn=<SumBackward0>)
# tensor(19.3295, grad_fn=<SumBackward0>)
# tensor(19.4074, grad_fn=<SumBackward0>)
# tensor(19.2338, grad_fn=<SumBackward0>)
# tensor(19.1939, grad_fn=<SumBackward0>)
# tensor(19.1876, grad_fn=<SumBackward0>)
# tensor(19.1819, grad_fn=<SumBackward0>)
# tensor(19.1799, grad_fn=<SumBackward0>)
# tensor(19.2652, grad_fn=<SumBackward0>)
# tensor(19.2757, grad_fn=<SumBackward0>)
# tensor(19.2024, grad_fn=<SumBackward0>)
# tensor(19.1968, grad_fn=<SumBackward0>)
# tensor(19.3091, grad_fn=<SumBackward0>)
# tensor(19.2592, grad_fn=<SumBackward0>)
# tensor(19.1264, grad_fn=<SumBackward0>)
# tensor(19.1489, grad_fn=<SumBackward0>)
# tensor(19.1145, grad_fn=<SumBackward0>)
# tensor(19.1452, grad_fn=<SumBackward0>)
# tensor(19.1048, grad_fn=<SumBackward0>)
# tensor(19.0227, grad_fn=<SumBackward0>)
# tensor(19.0383, grad_fn=<SumBackward0>)
# tensor(18.9940, grad_fn=<SumBackward0>)
# tensor(18.8386, grad_fn=<SumBackward0>)
# tensor(18.9496, grad_fn=<SumBackward0>)
# tensor(18.9334, grad_fn=<SumBackward0>)
# tensor(18.8999, grad_fn=<SumBackward0>)
# tensor(18.9531, grad_fn=<SumBackward0>)
# tensor(19.0855, grad_fn=<SumBackward0>)
# tensor(18.9251, grad_fn=<SumBackward0>)
# tensor(18.8401, grad_fn=<SumBackward0>)
# tensor(18.8470, grad_fn=<SumBackward0>)
# tensor(18.8492, grad_fn=<SumBackward0>)
# tensor(18.9488, grad_fn=<SumBackward0>)
# tensor(18.7926, grad_fn=<SumBackward0>)
# tensor(18.8071, grad_fn=<SumBackward0>)
# tensor(18.7762, grad_fn=<SumBackward0>)
# tensor(18.7307, grad_fn=<SumBackward0>)
# tensor(18.7411, grad_fn=<SumBackward0>)
# tensor(18.8408, grad_fn=<SumBackward0>)
# tensor(18.9687, grad_fn=<SumBackward0>)
# tensor(18.8447, grad_fn=<SumBackward0>)
# tensor(18.7830, grad_fn=<SumBackward0>)
# tensor(18.8626, grad_fn=<SumBackward0>)
# tensor(18.8541, grad_fn=<SumBackward0>)
# tensor(18.7779, grad_fn=<SumBackward0>)
# tensor(18.7031, grad_fn=<SumBackward0>)
# tensor(18.6900, grad_fn=<SumBackward0>)
# tensor(18.9518, grad_fn=<SumBackward0>)
# tensor(18.8206, grad_fn=<SumBackward0>)
# tensor(18.7655, grad_fn=<SumBackward0>)
# tensor(18.7567, grad_fn=<SumBackward0>)
# tensor(18.6351, grad_fn=<SumBackward0>)
# tensor(18.5617, grad_fn=<SumBackward0>)
# tensor(18.5789, grad_fn=<SumBackward0>)
# tensor(18.5478, grad_fn=<SumBackward0>)
# tensor(18.5612, grad_fn=<SumBackward0>)
# tensor(18.5627, grad_fn=<SumBackward0>)
# tensor(18.7358, grad_fn=<SumBackward0>)
# tensor(18.7008, grad_fn=<SumBackward0>)
# tensor(18.6104, grad_fn=<SumBackward0>)
# tensor(18.6081, grad_fn=<SumBackward0>)
# tensor(18.5912, grad_fn=<SumBackward0>)
# tensor(18.6382, grad_fn=<SumBackward0>)
# tensor(18.4856, grad_fn=<SumBackward0>)
# tensor(18.5041, grad_fn=<SumBackward0>)
# tensor(18.6171, grad_fn=<SumBackward0>)
# tensor(18.6413, grad_fn=<SumBackward0>)
# tensor(18.4592, grad_fn=<SumBackward0>)
# tensor(18.3015, grad_fn=<SumBackward0>)
# tensor(18.2927, grad_fn=<SumBackward0>)
# tensor(18.2475, grad_fn=<SumBackward0>)
# tensor(18.2078, grad_fn=<SumBackward0>)
# tensor(18.2016, grad_fn=<SumBackward0>)
# tensor(18.1794, grad_fn=<SumBackward0>)
# tensor(18.1753, grad_fn=<SumBackward0>)
# tensor(18.2202, grad_fn=<SumBackward0>)
# tensor(18.3141, grad_fn=<SumBackward0>)
# tensor(18.4398, grad_fn=<SumBackward0>)
# tensor(18.4151, grad_fn=<SumBackward0>)
# tensor(18.2726, grad_fn=<SumBackward0>)
# tensor(18.2787, grad_fn=<SumBackward0>)
# tensor(18.1675, grad_fn=<SumBackward0>)
# tensor(18.2181, grad_fn=<SumBackward0>)
# tensor(18.2781, grad_fn=<SumBackward0>)
# tensor(18.2406, grad_fn=<SumBackward0>)
# tensor(18.2506, grad_fn=<SumBackward0>)
# tensor(18.2326, grad_fn=<SumBackward0>)
# tensor(18.1835, grad_fn=<SumBackward0>)
# tensor(18.1830, grad_fn=<SumBackward0>)
# tensor(18.1471, grad_fn=<SumBackward0>)
# tensor(18.1339, grad_fn=<SumBackward0>)
# tensor(18.0767, grad_fn=<SumBackward0>)
# tensor(17.9980, grad_fn=<SumBackward0>)
# tensor(17.9481, grad_fn=<SumBackward0>)
# tensor(18.0244, grad_fn=<SumBackward0>)
# tensor(17.9919, grad_fn=<SumBackward0>)
# tensor(18.0918, grad_fn=<SumBackward0>)
# tensor(18.0887, grad_fn=<SumBackward0>)
# tensor(18.1013, grad_fn=<SumBackward0>)
# tensor(18.0718, grad_fn=<SumBackward0>)
# tensor(18.1892, grad_fn=<SumBackward0>)
# tensor(18.1855, grad_fn=<SumBackward0>)
# tensor(18.1579, grad_fn=<SumBackward0>)
# tensor(17.8644, grad_fn=<SumBackward0>)
# tensor(17.9204, grad_fn=<SumBackward0>)
# tensor(18.0562, grad_fn=<SumBackward0>)
# tensor(18.0034, grad_fn=<SumBackward0>)
# tensor(17.9358, grad_fn=<SumBackward0>)
# tensor(17.9077, grad_fn=<SumBackward0>)
# tensor(17.8493, grad_fn=<SumBackward0>)
# tensor(17.8690, grad_fn=<SumBackward0>)
# tensor(17.7699, grad_fn=<SumBackward0>)
# tensor(17.8472, grad_fn=<SumBackward0>)
# tensor(17.9053, grad_fn=<SumBackward0>)
# tensor(17.9973, grad_fn=<SumBackward0>)
# tensor(17.9201, grad_fn=<SumBackward0>)
# tensor(17.7900, grad_fn=<SumBackward0>)
# tensor(17.8062, grad_fn=<SumBackward0>)
# tensor(17.8301, grad_fn=<SumBackward0>)
# tensor(17.7477, grad_fn=<SumBackward0>)
# tensor(17.7515, grad_fn=<SumBackward0>)
# tensor(17.7650, grad_fn=<SumBackward0>)
# tensor(17.7371, grad_fn=<SumBackward0>)
# tensor(17.6368, grad_fn=<SumBackward0>)
# tensor(17.8006, grad_fn=<SumBackward0>)
# tensor(17.8723, grad_fn=<SumBackward0>)
# tensor(17.7864, grad_fn=<SumBackward0>)
# tensor(17.4285, grad_fn=<SumBackward0>)
# tensor(17.3101, grad_fn=<SumBackward0>)
# tensor(17.2938, grad_fn=<SumBackward0>)
# tensor(17.6374, grad_fn=<SumBackward0>)
# tensor(17.8819, grad_fn=<SumBackward0>)
# tensor(17.9270, grad_fn=<SumBackward0>)
# tensor(17.7264, grad_fn=<SumBackward0>)
# tensor(17.7788, grad_fn=<SumBackward0>)
# tensor(17.6974, grad_fn=<SumBackward0>)
# tensor(17.6106, grad_fn=<SumBackward0>)
# tensor(17.5656, grad_fn=<SumBackward0>)
# tensor(17.2235, grad_fn=<SumBackward0>)
# tensor(17.4458, grad_fn=<SumBackward0>)
# tensor(17.4044, grad_fn=<SumBackward0>)
# tensor(17.2235, grad_fn=<SumBackward0>)
# tensor(17.4172, grad_fn=<SumBackward0>)
# tensor(17.3357, grad_fn=<SumBackward0>)
# tensor(17.1358, grad_fn=<SumBackward0>)
# tensor(17.1626, grad_fn=<SumBackward0>)
# tensor(17.1412, grad_fn=<SumBackward0>)
# tensor(17.0874, grad_fn=<SumBackward0>)
# tensor(17.1528, grad_fn=<SumBackward0>)
# tensor(17.0879, grad_fn=<SumBackward0>)
# tensor(17.1734, grad_fn=<SumBackward0>)
# tensor(17.0317, grad_fn=<SumBackward0>)
# tensor(16.9532, grad_fn=<SumBackward0>)
# tensor(17.0858, grad_fn=<SumBackward0>)
# tensor(17.0284, grad_fn=<SumBackward0>)
# tensor(17.0918, grad_fn=<SumBackward0>)
# tensor(17.1067, grad_fn=<SumBackward0>)
# tensor(16.9337, grad_fn=<SumBackward0>)
# tensor(16.8924, grad_fn=<SumBackward0>)
# tensor(16.9483, grad_fn=<SumBackward0>)
# tensor(17.1686, grad_fn=<SumBackward0>)
# tensor(17.0544, grad_fn=<SumBackward0>)
# tensor(16.9871, grad_fn=<SumBackward0>)
# tensor(17.0116, grad_fn=<SumBackward0>)
# tensor(17.0647, grad_fn=<SumBackward0>)
# tensor(17.0245, grad_fn=<SumBackward0>)
# tensor(16.9643, grad_fn=<SumBackward0>)
# tensor(16.8942, grad_fn=<SumBackward0>)
# tensor(16.9407, grad_fn=<SumBackward0>)
# tensor(17.0344, grad_fn=<SumBackward0>)
# tensor(17.1457, grad_fn=<SumBackward0>)
# tensor(16.9814, grad_fn=<SumBackward0>)
# tensor(16.9336, grad_fn=<SumBackward0>)
# tensor(16.9379, grad_fn=<SumBackward0>)
# tensor(16.8428, grad_fn=<SumBackward0>)
# tensor(16.8912, grad_fn=<SumBackward0>)
# tensor(16.8936, grad_fn=<SumBackward0>)
# tensor(17.0527, grad_fn=<SumBackward0>)
# tensor(16.7285, grad_fn=<SumBackward0>)
# tensor(16.6735, grad_fn=<SumBackward0>)
# tensor(16.7038, grad_fn=<SumBackward0>)
# tensor(16.8621, grad_fn=<SumBackward0>)
# tensor(16.6987, grad_fn=<SumBackward0>)
# tensor(16.6438, grad_fn=<SumBackward0>)
# tensor(16.5844, grad_fn=<SumBackward0>)
# tensor(16.5727, grad_fn=<SumBackward0>)
# tensor(16.5951, grad_fn=<SumBackward0>)
# tensor(16.6010, grad_fn=<SumBackward0>)
# tensor(16.6846, grad_fn=<SumBackward0>)
# tensor(16.6942, grad_fn=<SumBackward0>)
# tensor(16.6131, grad_fn=<SumBackward0>)
# tensor(16.5606, grad_fn=<SumBackward0>)
# tensor(16.5577, grad_fn=<SumBackward0>)
# tensor(16.7502, grad_fn=<SumBackward0>)
# tensor(16.6452, grad_fn=<SumBackward0>)
# tensor(16.5202, grad_fn=<SumBackward0>)
# tensor(16.4853, grad_fn=<SumBackward0>)
# tensor(16.6050, grad_fn=<SumBackward0>)
# tensor(16.5310, grad_fn=<SumBackward0>)
# tensor(16.5417, grad_fn=<SumBackward0>)
# tensor(16.5591, grad_fn=<SumBackward0>)
# tensor(16.6739, grad_fn=<SumBackward0>)
# tensor(16.6263, grad_fn=<SumBackward0>)
# tensor(16.4886, grad_fn=<SumBackward0>)
# tensor(16.5715, grad_fn=<SumBackward0>)
# tensor(16.5279, grad_fn=<SumBackward0>)
# tensor(16.4740, grad_fn=<SumBackward0>)
# tensor(16.6399, grad_fn=<SumBackward0>)
# tensor(16.6047, grad_fn=<SumBackward0>)
# tensor(16.3062, grad_fn=<SumBackward0>)
# tensor(16.5389, grad_fn=<SumBackward0>)
# tensor(16.5428, grad_fn=<SumBackward0>)
# tensor(16.3185, grad_fn=<SumBackward0>)
# tensor(16.3454, grad_fn=<SumBackward0>)
# tensor(16.1318, grad_fn=<SumBackward0>)
# tensor(16.2941, grad_fn=<SumBackward0>)
# tensor(16.3919, grad_fn=<SumBackward0>)
# tensor(16.2621, grad_fn=<SumBackward0>)
# tensor(16.2188, grad_fn=<SumBackward0>)
# tensor(16.1622, grad_fn=<SumBackward0>)
# tensor(16.3987, grad_fn=<SumBackward0>)
# tensor(16.2275, grad_fn=<SumBackward0>)
# tensor(16.1749, grad_fn=<SumBackward0>)
# tensor(16.2564, grad_fn=<SumBackward0>)
# tensor(16.2622, grad_fn=<SumBackward0>)
# tensor(16.3501, grad_fn=<SumBackward0>)
# tensor(16.3208, grad_fn=<SumBackward0>)
# tensor(16.2917, grad_fn=<SumBackward0>)
# tensor(16.1912, grad_fn=<SumBackward0>)
# tensor(16.2579, grad_fn=<SumBackward0>)
# tensor(16.2150, grad_fn=<SumBackward0>)
# tensor(16.2225, grad_fn=<SumBackward0>)
# tensor(16.2282, grad_fn=<SumBackward0>)
# tensor(16.1172, grad_fn=<SumBackward0>)
# tensor(16.2804, grad_fn=<SumBackward0>)
# tensor(16.2643, grad_fn=<SumBackward0>)
# tensor(16.1776, grad_fn=<SumBackward0>)
# tensor(16.4084, grad_fn=<SumBackward0>)
# tensor(16.3965, grad_fn=<SumBackward0>)
# tensor(16.4718, grad_fn=<SumBackward0>)
# tensor(16.2893, grad_fn=<SumBackward0>)
# tensor(16.2739, grad_fn=<SumBackward0>)
# tensor(16.2550, grad_fn=<SumBackward0>)
# tensor(16.1668, grad_fn=<SumBackward0>)
# tensor(16.2250, grad_fn=<SumBackward0>)
# tensor(16.2485, grad_fn=<SumBackward0>)
# tensor(16.2113, grad_fn=<SumBackward0>)
# tensor(16.1297, grad_fn=<SumBackward0>)
# tensor(16.3368, grad_fn=<SumBackward0>)
# tensor(16.2648, grad_fn=<SumBackward0>)
# tensor(16.2107, grad_fn=<SumBackward0>)
# tensor(15.9635, grad_fn=<SumBackward0>)
# tensor(15.9517, grad_fn=<SumBackward0>)
# tensor(16.3574, grad_fn=<SumBackward0>)
# tensor(16.4365, grad_fn=<SumBackward0>)
# tensor(16.3625, grad_fn=<SumBackward0>)
# tensor(16.3033, grad_fn=<SumBackward0>)
# tensor(16.2334, grad_fn=<SumBackward0>)
# tensor(16.0926, grad_fn=<SumBackward0>)
# tensor(16.1006, grad_fn=<SumBackward0>)
# tensor(16.1973, grad_fn=<SumBackward0>)
# tensor(16.1640, grad_fn=<SumBackward0>)
# tensor(16.0787, grad_fn=<SumBackward0>)
# tensor(16.0549, grad_fn=<SumBackward0>)
# tensor(15.9579, grad_fn=<SumBackward0>)
# tensor(15.8697, grad_fn=<SumBackward0>)
# tensor(15.8291, grad_fn=<SumBackward0>)
# tensor(15.7576, grad_fn=<SumBackward0>)
# tensor(15.9088, grad_fn=<SumBackward0>)
# tensor(15.9068, grad_fn=<SumBackward0>)
# tensor(15.8537, grad_fn=<SumBackward0>)
# tensor(15.9049, grad_fn=<SumBackward0>)
# tensor(16.0180, grad_fn=<SumBackward0>)
# tensor(16.2799, grad_fn=<SumBackward0>)
# tensor(16.1640, grad_fn=<SumBackward0>)
# tensor(16.2234, grad_fn=<SumBackward0>)
# tensor(15.9574, grad_fn=<SumBackward0>)
# tensor(15.8867, grad_fn=<SumBackward0>)
# tensor(15.9553, grad_fn=<SumBackward0>)
# tensor(15.7146, grad_fn=<SumBackward0>)
# tensor(15.7135, grad_fn=<SumBackward0>)
# tensor(15.6688, grad_fn=<SumBackward0>)
# tensor(15.6618, grad_fn=<SumBackward0>)
# tensor(15.5592, grad_fn=<SumBackward0>)
# tensor(15.5678, grad_fn=<SumBackward0>)
# tensor(15.6027, grad_fn=<SumBackward0>)
# tensor(15.6407, grad_fn=<SumBackward0>)
# tensor(15.8037, grad_fn=<SumBackward0>)
# tensor(15.7361, grad_fn=<SumBackward0>)
# tensor(15.6416, grad_fn=<SumBackward0>)
# tensor(15.5605, grad_fn=<SumBackward0>)
# tensor(15.4040, grad_fn=<SumBackward0>)
# tensor(15.4155, grad_fn=<SumBackward0>)
# tensor(15.4141, grad_fn=<SumBackward0>)
# tensor(15.6062, grad_fn=<SumBackward0>)
# tensor(15.7019, grad_fn=<SumBackward0>)
# tensor(15.5777, grad_fn=<SumBackward0>)
# tensor(15.6068, grad_fn=<SumBackward0>)
# tensor(15.6956, grad_fn=<SumBackward0>)
# tensor(15.7126, grad_fn=<SumBackward0>)
# tensor(15.5275, grad_fn=<SumBackward0>)
# tensor(15.5653, grad_fn=<SumBackward0>)
# tensor(15.5409, grad_fn=<SumBackward0>)
# tensor(15.6882, grad_fn=<SumBackward0>)
# tensor(15.7941, grad_fn=<SumBackward0>)
# tensor(15.7752, grad_fn=<SumBackward0>)
# tensor(15.5312, grad_fn=<SumBackward0>)
# tensor(15.5990, grad_fn=<SumBackward0>)
# tensor(15.6754, grad_fn=<SumBackward0>)
# tensor(15.7536, grad_fn=<SumBackward0>)
# tensor(15.5233, grad_fn=<SumBackward0>)
# tensor(15.5266, grad_fn=<SumBackward0>)
# tensor(15.5156, grad_fn=<SumBackward0>)
# tensor(15.5143, grad_fn=<SumBackward0>)
# tensor(15.4578, grad_fn=<SumBackward0>)
# tensor(15.4162, grad_fn=<SumBackward0>)
# tensor(15.3715, grad_fn=<SumBackward0>)
# tensor(15.4378, grad_fn=<SumBackward0>)
# tensor(15.4154, grad_fn=<SumBackward0>)
# tensor(15.3831, grad_fn=<SumBackward0>)
# tensor(15.6040, grad_fn=<SumBackward0>)
# tensor(15.4676, grad_fn=<SumBackward0>)
# tensor(15.1457, grad_fn=<SumBackward0>)
# tensor(15.3031, grad_fn=<SumBackward0>)
# tensor(15.4504, grad_fn=<SumBackward0>)
# tensor(15.4117, grad_fn=<SumBackward0>)
# tensor(15.2082, grad_fn=<SumBackward0>)
# tensor(15.2982, grad_fn=<SumBackward0>)
# tensor(15.1532, grad_fn=<SumBackward0>)
# tensor(15.1437, grad_fn=<SumBackward0>)
# tensor(15.4011, grad_fn=<SumBackward0>)
# tensor(15.3014, grad_fn=<SumBackward0>)
# tensor(15.2870, grad_fn=<SumBackward0>)
# tensor(15.3531, grad_fn=<SumBackward0>)
# tensor(15.2211, grad_fn=<SumBackward0>)
# tensor(15.2447, grad_fn=<SumBackward0>)
# tensor(15.3508, grad_fn=<SumBackward0>)
# tensor(15.1570, grad_fn=<SumBackward0>)
# tensor(15.1608, grad_fn=<SumBackward0>)
# tensor(15.2137, grad_fn=<SumBackward0>)
# tensor(15.3415, grad_fn=<SumBackward0>)
# tensor(15.2463, grad_fn=<SumBackward0>)
# tensor(15.3021, grad_fn=<SumBackward0>)
# tensor(15.1445, grad_fn=<SumBackward0>)
# tensor(15.0757, grad_fn=<SumBackward0>)
# tensor(15.3141, grad_fn=<SumBackward0>)
# tensor(15.4271, grad_fn=<SumBackward0>)
# tensor(15.4854, grad_fn=<SumBackward0>)
# tensor(15.3412, grad_fn=<SumBackward0>)
# tensor(15.2489, grad_fn=<SumBackward0>)
# tensor(15.3786, grad_fn=<SumBackward0>)
# tensor(15.4392, grad_fn=<SumBackward0>)
# tensor(15.6015, grad_fn=<SumBackward0>)
# tensor(15.2399, grad_fn=<SumBackward0>)
# tensor(15.3998, grad_fn=<SumBackward0>)
# tensor(15.0034, grad_fn=<SumBackward0>)
# tensor(15.0968, grad_fn=<SumBackward0>)
# tensor(14.8998, grad_fn=<SumBackward0>)
# tensor(14.7571, grad_fn=<SumBackward0>)
# tensor(14.7132, grad_fn=<SumBackward0>)
# tensor(14.7494, grad_fn=<SumBackward0>)
# tensor(14.9336, grad_fn=<SumBackward0>)
# tensor(14.7183, grad_fn=<SumBackward0>)
# tensor(14.5879, grad_fn=<SumBackward0>)
# tensor(14.7717, grad_fn=<SumBackward0>)
# tensor(14.7628, grad_fn=<SumBackward0>)
# tensor(14.7645, grad_fn=<SumBackward0>)
# tensor(14.9032, grad_fn=<SumBackward0>)
# tensor(14.9533, grad_fn=<SumBackward0>)
# tensor(14.9818, grad_fn=<SumBackward0>)
# tensor(15.0894, grad_fn=<SumBackward0>)
# tensor(14.8765, grad_fn=<SumBackward0>)
# tensor(14.9859, grad_fn=<SumBackward0>)
# tensor(15.0201, grad_fn=<SumBackward0>)
# tensor(14.8196, grad_fn=<SumBackward0>)
# tensor(14.7436, grad_fn=<SumBackward0>)
# tensor(14.8116, grad_fn=<SumBackward0>)
# tensor(14.6374, grad_fn=<SumBackward0>)
# tensor(14.6362, grad_fn=<SumBackward0>)
# tensor(14.8098, grad_fn=<SumBackward0>)
# tensor(14.7346, grad_fn=<SumBackward0>)
# tensor(14.6240, grad_fn=<SumBackward0>)
# tensor(14.5789, grad_fn=<SumBackward0>)
# tensor(14.9413, grad_fn=<SumBackward0>)
# tensor(14.7656, grad_fn=<SumBackward0>)
# tensor(14.4861, grad_fn=<SumBackward0>)
# tensor(14.5991, grad_fn=<SumBackward0>)
# tensor(14.6934, grad_fn=<SumBackward0>)
# tensor(14.9265, grad_fn=<SumBackward0>)
# tensor(14.7960, grad_fn=<SumBackward0>)
# tensor(14.6537, grad_fn=<SumBackward0>)
# tensor(14.7704, grad_fn=<SumBackward0>)
# tensor(14.8033, grad_fn=<SumBackward0>)
# tensor(14.6981, grad_fn=<SumBackward0>)
# tensor(14.6423, grad_fn=<SumBackward0>)
# tensor(14.4618, grad_fn=<SumBackward0>)
# tensor(14.3290, grad_fn=<SumBackward0>)
# tensor(14.3139, grad_fn=<SumBackward0>)
# tensor(14.3017, grad_fn=<SumBackward0>)
# tensor(14.2662, grad_fn=<SumBackward0>)
# tensor(14.3302, grad_fn=<SumBackward0>)
# tensor(14.5318, grad_fn=<SumBackward0>)
# tensor(14.3122, grad_fn=<SumBackward0>)
# tensor(14.3352, grad_fn=<SumBackward0>)
# tensor(14.4633, grad_fn=<SumBackward0>)
# tensor(14.5208, grad_fn=<SumBackward0>)
# tensor(14.5131, grad_fn=<SumBackward0>)
# tensor(14.5890, grad_fn=<SumBackward0>)
# tensor(14.5479, grad_fn=<SumBackward0>)
# tensor(14.4471, grad_fn=<SumBackward0>)
# tensor(14.5468, grad_fn=<SumBackward0>)
# tensor(14.5684, grad_fn=<SumBackward0>)
# tensor(14.7991, grad_fn=<SumBackward0>)
# tensor(14.6907, grad_fn=<SumBackward0>)
# tensor(14.4015, grad_fn=<SumBackward0>)
# tensor(14.2448, grad_fn=<SumBackward0>)
# tensor(14.2084, grad_fn=<SumBackward0>)
# tensor(14.4619, grad_fn=<SumBackward0>)
# tensor(14.6302, grad_fn=<SumBackward0>)
# tensor(14.2853, grad_fn=<SumBackward0>)
# tensor(14.4421, grad_fn=<SumBackward0>)
# tensor(14.4518, grad_fn=<SumBackward0>)
# tensor(14.3550, grad_fn=<SumBackward0>)
# tensor(14.3924, grad_fn=<SumBackward0>)
# tensor(14.1295, grad_fn=<SumBackward0>)
# tensor(14.1255, grad_fn=<SumBackward0>)
# tensor(14.1504, grad_fn=<SumBackward0>)
# tensor(14.0850, grad_fn=<SumBackward0>)
# tensor(13.9810, grad_fn=<SumBackward0>)
# tensor(13.9115, grad_fn=<SumBackward0>)
# tensor(13.7738, grad_fn=<SumBackward0>)
# tensor(14.2201, grad_fn=<SumBackward0>)
# tensor(14.1455, grad_fn=<SumBackward0>)
# tensor(14.1693, grad_fn=<SumBackward0>)
# tensor(13.8683, grad_fn=<SumBackward0>)
# tensor(14.0427, grad_fn=<SumBackward0>)
# tensor(13.9423, grad_fn=<SumBackward0>)
# tensor(14.4541, grad_fn=<SumBackward0>)
# tensor(14.0010, grad_fn=<SumBackward0>)
# tensor(14.3157, grad_fn=<SumBackward0>)
# tensor(13.9188, grad_fn=<SumBackward0>)
# tensor(13.7971, grad_fn=<SumBackward0>)
# tensor(13.9023, grad_fn=<SumBackward0>)
# tensor(13.9021, grad_fn=<SumBackward0>)
# tensor(13.9224, grad_fn=<SumBackward0>)
# tensor(13.9029, grad_fn=<SumBackward0>)
# tensor(13.9943, grad_fn=<SumBackward0>)
# tensor(13.7877, grad_fn=<SumBackward0>)
# tensor(13.7516, grad_fn=<SumBackward0>)
# tensor(13.6181, grad_fn=<SumBackward0>)
# tensor(13.8516, grad_fn=<SumBackward0>)
# tensor(14.0239, grad_fn=<SumBackward0>)
# tensor(13.9084, grad_fn=<SumBackward0>)
# tensor(13.7276, grad_fn=<SumBackward0>)
# tensor(13.7552, grad_fn=<SumBackward0>)
# tensor(13.7274, grad_fn=<SumBackward0>)
# tensor(13.7290, grad_fn=<SumBackward0>)
# tensor(14.0049, grad_fn=<SumBackward0>)
# tensor(14.0040, grad_fn=<SumBackward0>)
# tensor(13.9043, grad_fn=<SumBackward0>)
# tensor(13.8785, grad_fn=<SumBackward0>)
# tensor(14.1406, grad_fn=<SumBackward0>)
# tensor(13.6460, grad_fn=<SumBackward0>)
# tensor(13.8917, grad_fn=<SumBackward0>)
# tensor(13.7568, grad_fn=<SumBackward0>)
# tensor(13.8003, grad_fn=<SumBackward0>)
# tensor(13.8145, grad_fn=<SumBackward0>)
# tensor(13.9664, grad_fn=<SumBackward0>)
# tensor(14.0475, grad_fn=<SumBackward0>)
# tensor(13.9498, grad_fn=<SumBackward0>)
# tensor(13.9218, grad_fn=<SumBackward0>)
# tensor(13.6947, grad_fn=<SumBackward0>)
# tensor(13.6446, grad_fn=<SumBackward0>)
# tensor(13.9319, grad_fn=<SumBackward0>)
# tensor(13.7118, grad_fn=<SumBackward0>)
# tensor(13.8338, grad_fn=<SumBackward0>)
# tensor(13.8658, grad_fn=<SumBackward0>)
# tensor(13.7499, grad_fn=<SumBackward0>)
# tensor(13.7561, grad_fn=<SumBackward0>)
# tensor(13.6689, grad_fn=<SumBackward0>)
# tensor(13.7292, grad_fn=<SumBackward0>)
# tensor(13.5882, grad_fn=<SumBackward0>)
# tensor(13.6205, grad_fn=<SumBackward0>)
# tensor(13.6629, grad_fn=<SumBackward0>)
# tensor(13.5924, grad_fn=<SumBackward0>)
# tensor(13.5383, grad_fn=<SumBackward0>)
# tensor(13.6494, grad_fn=<SumBackward0>)
# tensor(13.5961, grad_fn=<SumBackward0>)
# tensor(13.5314, grad_fn=<SumBackward0>)
# tensor(13.6327, grad_fn=<SumBackward0>)
# tensor(13.4716, grad_fn=<SumBackward0>)
# tensor(13.5079, grad_fn=<SumBackward0>)
# tensor(13.4471, grad_fn=<SumBackward0>)
# tensor(13.8036, grad_fn=<SumBackward0>)
# tensor(13.7427, grad_fn=<SumBackward0>)
# tensor(13.5037, grad_fn=<SumBackward0>)
# tensor(13.5338, grad_fn=<SumBackward0>)
# tensor(13.6033, grad_fn=<SumBackward0>)
# tensor(13.7136, grad_fn=<SumBackward0>)
# tensor(13.5115, grad_fn=<SumBackward0>)
# tensor(13.6332, grad_fn=<SumBackward0>)
# tensor(13.7712, grad_fn=<SumBackward0>)
# tensor(13.5088, grad_fn=<SumBackward0>)
# tensor(13.5096, grad_fn=<SumBackward0>)
# tensor(13.4905, grad_fn=<SumBackward0>)
# tensor(13.9137, grad_fn=<SumBackward0>)
# tensor(13.8417, grad_fn=<SumBackward0>)
# tensor(13.5855, grad_fn=<SumBackward0>)
# tensor(13.6752, grad_fn=<SumBackward0>)
# tensor(13.6043, grad_fn=<SumBackward0>)
# tensor(13.6334, grad_fn=<SumBackward0>)
# tensor(13.5383, grad_fn=<SumBackward0>)
# tensor(13.4435, grad_fn=<SumBackward0>)
# tensor(13.3587, grad_fn=<SumBackward0>)
# tensor(13.6764, grad_fn=<SumBackward0>)
# tensor(13.8608, grad_fn=<SumBackward0>)
# tensor(13.9816, grad_fn=<SumBackward0>)
# tensor(13.3326, grad_fn=<SumBackward0>)
# tensor(13.5303, grad_fn=<SumBackward0>)
# tensor(13.3181, grad_fn=<SumBackward0>)
# tensor(13.2988, grad_fn=<SumBackward0>)
# tensor(13.3314, grad_fn=<SumBackward0>)
# tensor(13.0741, grad_fn=<SumBackward0>)
# tensor(13.2413, grad_fn=<SumBackward0>)
# tensor(13.1339, grad_fn=<SumBackward0>)
# tensor(13.1022, grad_fn=<SumBackward0>)
# tensor(13.1370, grad_fn=<SumBackward0>)
# tensor(13.2430, grad_fn=<SumBackward0>)
# tensor(13.2958, grad_fn=<SumBackward0>)
# tensor(13.4302, grad_fn=<SumBackward0>)
# tensor(13.3860, grad_fn=<SumBackward0>)
# tensor(13.4349, grad_fn=<SumBackward0>)
# tensor(13.3001, grad_fn=<SumBackward0>)
# tensor(13.2585, grad_fn=<SumBackward0>)
# tensor(13.0736, grad_fn=<SumBackward0>)
# tensor(13.3448, grad_fn=<SumBackward0>)
# tensor(13.2136, grad_fn=<SumBackward0>)
# tensor(13.7387, grad_fn=<SumBackward0>)
# tensor(13.2157, grad_fn=<SumBackward0>)
# tensor(13.0602, grad_fn=<SumBackward0>)
# tensor(13.2579, grad_fn=<SumBackward0>)
# tensor(12.8886, grad_fn=<SumBackward0>)
# tensor(13.3739, grad_fn=<SumBackward0>)
# tensor(12.9907, grad_fn=<SumBackward0>)
# tensor(13.5355, grad_fn=<SumBackward0>)
# tensor(13.1790, grad_fn=<SumBackward0>)
# tensor(13.3095, grad_fn=<SumBackward0>)
# tensor(13.1425, grad_fn=<SumBackward0>)
# tensor(13.1140, grad_fn=<SumBackward0>)
# tensor(13.1906, grad_fn=<SumBackward0>)
# tensor(13.0922, grad_fn=<SumBackward0>)
# tensor(13.1921, grad_fn=<SumBackward0>)
# tensor(13.0818, grad_fn=<SumBackward0>)
# tensor(13.1690, grad_fn=<SumBackward0>)
# tensor(13.5546, grad_fn=<SumBackward0>)
# tensor(13.2695, grad_fn=<SumBackward0>)
# tensor(13.1962, grad_fn=<SumBackward0>)
# tensor(12.9977, grad_fn=<SumBackward0>)
# tensor(12.9654, grad_fn=<SumBackward0>)
# tensor(12.8682, grad_fn=<SumBackward0>)
# tensor(12.9457, grad_fn=<SumBackward0>)
# tensor(12.9211, grad_fn=<SumBackward0>)
# tensor(13.2399, grad_fn=<SumBackward0>)
# tensor(12.9237, grad_fn=<SumBackward0>)
# tensor(13.2353, grad_fn=<SumBackward0>)
# tensor(12.9579, grad_fn=<SumBackward0>)
# tensor(13.2441, grad_fn=<SumBackward0>)
# tensor(13.2298, grad_fn=<SumBackward0>)
# tensor(13.3233, grad_fn=<SumBackward0>)
# tensor(13.1824, grad_fn=<SumBackward0>)
# tensor(13.2794, grad_fn=<SumBackward0>)
# tensor(13.0766, grad_fn=<SumBackward0>)
# tensor(13.0451, grad_fn=<SumBackward0>)
# tensor(13.3251, grad_fn=<SumBackward0>)
# tensor(13.3233, grad_fn=<SumBackward0>)
# tensor(13.0297, grad_fn=<SumBackward0>)
# tensor(13.0065, grad_fn=<SumBackward0>)
# tensor(13.0169, grad_fn=<SumBackward0>)
# tensor(12.7186, grad_fn=<SumBackward0>)
# tensor(12.8953, grad_fn=<SumBackward0>)
# tensor(13.3399, grad_fn=<SumBackward0>)
# tensor(13.1082, grad_fn=<SumBackward0>)
# tensor(13.2466, grad_fn=<SumBackward0>)
# tensor(13.2891, grad_fn=<SumBackward0>)
# tensor(13.1261, grad_fn=<SumBackward0>)
# tensor(12.8769, grad_fn=<SumBackward0>)
# tensor(12.6550, grad_fn=<SumBackward0>)
# tensor(12.6624, grad_fn=<SumBackward0>)
# tensor(12.8464, grad_fn=<SumBackward0>)
# tensor(12.8767, grad_fn=<SumBackward0>)
# tensor(12.8937, grad_fn=<SumBackward0>)
# tensor(12.9967, grad_fn=<SumBackward0>)
# tensor(12.8058, grad_fn=<SumBackward0>)
# tensor(12.8452, grad_fn=<SumBackward0>)
# tensor(12.8624, grad_fn=<SumBackward0>)
# tensor(13.0083, grad_fn=<SumBackward0>)
# tensor(12.8820, grad_fn=<SumBackward0>)
# tensor(12.7386, grad_fn=<SumBackward0>)
# tensor(12.8530, grad_fn=<SumBackward0>)
# tensor(13.0997, grad_fn=<SumBackward0>)
# tensor(13.0848, grad_fn=<SumBackward0>)
# tensor(13.0351, grad_fn=<SumBackward0>)
# tensor(12.8544, grad_fn=<SumBackward0>)
# tensor(12.6238, grad_fn=<SumBackward0>)
# tensor(12.8432, grad_fn=<SumBackward0>)
# tensor(12.5619, grad_fn=<SumBackward0>)
# tensor(12.6749, grad_fn=<SumBackward0>)
# tensor(12.6834, grad_fn=<SumBackward0>)
# tensor(12.5839, grad_fn=<SumBackward0>)
# tensor(13.0671, grad_fn=<SumBackward0>)
# tensor(13.0411, grad_fn=<SumBackward0>)
# tensor(12.9892, grad_fn=<SumBackward0>)
# tensor(12.7148, grad_fn=<SumBackward0>)
# tensor(12.8521, grad_fn=<SumBackward0>)
# tensor(12.6294, grad_fn=<SumBackward0>)
# tensor(13.0075, grad_fn=<SumBackward0>)
# tensor(13.1692, grad_fn=<SumBackward0>)
# tensor(13.2019, grad_fn=<SumBackward0>)
# tensor(13.0321, grad_fn=<SumBackward0>)
# tensor(12.9505, grad_fn=<SumBackward0>)
# tensor(12.5917, grad_fn=<SumBackward0>)
# tensor(12.7238, grad_fn=<SumBackward0>)
# tensor(12.6688, grad_fn=<SumBackward0>)
# tensor(12.5210, grad_fn=<SumBackward0>)
# tensor(12.4694, grad_fn=<SumBackward0>)
# tensor(12.4987, grad_fn=<SumBackward0>)
# tensor(12.5729, grad_fn=<SumBackward0>)
# tensor(12.4771, grad_fn=<SumBackward0>)
# tensor(12.5644, grad_fn=<SumBackward0>)
# tensor(12.5106, grad_fn=<SumBackward0>)
# tensor(12.7145, grad_fn=<SumBackward0>)
# tensor(13.1410, grad_fn=<SumBackward0>)
# tensor(12.9339, grad_fn=<SumBackward0>)
# tensor(12.6133, grad_fn=<SumBackward0>)
# tensor(13.0393, grad_fn=<SumBackward0>)
# tensor(12.4553, grad_fn=<SumBackward0>)
# tensor(12.5749, grad_fn=<SumBackward0>)
# tensor(12.8091, grad_fn=<SumBackward0>)
# tensor(12.4157, grad_fn=<SumBackward0>)
# tensor(12.8750, grad_fn=<SumBackward0>)
# tensor(12.6762, grad_fn=<SumBackward0>)
# tensor(12.5434, grad_fn=<SumBackward0>)
# tensor(12.5464, grad_fn=<SumBackward0>)
# tensor(12.5915, grad_fn=<SumBackward0>)
# tensor(12.4246, grad_fn=<SumBackward0>)
# tensor(12.6585, grad_fn=<SumBackward0>)
# tensor(12.7040, grad_fn=<SumBackward0>)
# tensor(12.5766, grad_fn=<SumBackward0>)
# tensor(12.7043, grad_fn=<SumBackward0>)
# tensor(13.0101, grad_fn=<SumBackward0>)
# tensor(12.7007, grad_fn=<SumBackward0>)
# tensor(13.4016, grad_fn=<SumBackward0>)
# tensor(13.0440, grad_fn=<SumBackward0>)
# tensor(12.7078, grad_fn=<SumBackward0>)
# tensor(12.5704, grad_fn=<SumBackward0>)
# tensor(12.5827, grad_fn=<SumBackward0>)
# tensor(12.5904, grad_fn=<SumBackward0>)
# tensor(12.5273, grad_fn=<SumBackward0>)
# tensor(12.3123, grad_fn=<SumBackward0>)
# tensor(12.4031, grad_fn=<SumBackward0>)
# tensor(12.3072, grad_fn=<SumBackward0>)
# tensor(12.4310, grad_fn=<SumBackward0>)
# tensor(12.3284, grad_fn=<SumBackward0>)
# tensor(12.3924, grad_fn=<SumBackward0>)
# tensor(12.4469, grad_fn=<SumBackward0>)
# tensor(12.2424, grad_fn=<SumBackward0>)
# tensor(12.1521, grad_fn=<SumBackward0>)
# tensor(12.1854, grad_fn=<SumBackward0>)
# tensor(12.2445, grad_fn=<SumBackward0>)
# tensor(12.1194, grad_fn=<SumBackward0>)
# tensor(12.2814, grad_fn=<SumBackward0>)
# tensor(12.2034, grad_fn=<SumBackward0>)
# tensor(12.3205, grad_fn=<SumBackward0>)
# tensor(12.2848, grad_fn=<SumBackward0>)
# tensor(12.2684, grad_fn=<SumBackward0>)
# tensor(12.3422, grad_fn=<SumBackward0>)
# tensor(12.3958, grad_fn=<SumBackward0>)
# tensor(12.3673, grad_fn=<SumBackward0>)
# tensor(12.7360, grad_fn=<SumBackward0>)
# tensor(12.3594, grad_fn=<SumBackward0>)
# tensor(12.5425, grad_fn=<SumBackward0>)
# tensor(12.5511, grad_fn=<SumBackward0>)
# tensor(13.3272, grad_fn=<SumBackward0>)
# tensor(12.6260, grad_fn=<SumBackward0>)
# tensor(13.0096, grad_fn=<SumBackward0>)
# tensor(12.9921, grad_fn=<SumBackward0>)
# tensor(13.1239, grad_fn=<SumBackward0>)
# tensor(12.3847, grad_fn=<SumBackward0>)
# tensor(12.3309, grad_fn=<SumBackward0>)
# tensor(12.2803, grad_fn=<SumBackward0>)
# tensor(12.3024, grad_fn=<SumBackward0>)
# tensor(12.1729, grad_fn=<SumBackward0>)
# tensor(12.3866, grad_fn=<SumBackward0>)
# tensor(12.1576, grad_fn=<SumBackward0>)
# tensor(12.4391, grad_fn=<SumBackward0>)
# tensor(12.5332, grad_fn=<SumBackward0>)
# tensor(12.6557, grad_fn=<SumBackward0>)
# tensor(12.3526, grad_fn=<SumBackward0>)
# tensor(12.4542, grad_fn=<SumBackward0>)
# tensor(12.2453, grad_fn=<SumBackward0>)
# tensor(12.0847, grad_fn=<SumBackward0>)
# tensor(12.1763, grad_fn=<SumBackward0>)
# tensor(12.0520, grad_fn=<SumBackward0>)
# tensor(12.1221, grad_fn=<SumBackward0>)
# tensor(12.1418, grad_fn=<SumBackward0>)
# tensor(12.3430, grad_fn=<SumBackward0>)
# tensor(12.1247, grad_fn=<SumBackward0>)
# tensor(12.4952, grad_fn=<SumBackward0>)
# tensor(12.5417, grad_fn=<SumBackward0>)
# tensor(12.3724, grad_fn=<SumBackward0>)
# tensor(11.9589, grad_fn=<SumBackward0>)
# tensor(11.9990, grad_fn=<SumBackward0>)
# tensor(11.9410, grad_fn=<SumBackward0>)
# tensor(12.2761, grad_fn=<SumBackward0>)
# tensor(12.2037, grad_fn=<SumBackward0>)
# tensor(12.4422, grad_fn=<SumBackward0>)
# tensor(12.2600, grad_fn=<SumBackward0>)
# tensor(11.9752, grad_fn=<SumBackward0>)
# tensor(12.0051, grad_fn=<SumBackward0>)
# tensor(12.4183, grad_fn=<SumBackward0>)
# tensor(12.4386, grad_fn=<SumBackward0>)
# tensor(12.2847, grad_fn=<SumBackward0>)
# tensor(12.8589, grad_fn=<SumBackward0>)
# tensor(12.4726, grad_fn=<SumBackward0>)
# tensor(12.2208, grad_fn=<SumBackward0>)
# tensor(12.0427, grad_fn=<SumBackward0>)
# tensor(12.1647, grad_fn=<SumBackward0>)
# tensor(11.9400, grad_fn=<SumBackward0>)
# tensor(12.1758, grad_fn=<SumBackward0>)
# tensor(11.9855, grad_fn=<SumBackward0>)
# tensor(12.0475, grad_fn=<SumBackward0>)
# tensor(11.9599, grad_fn=<SumBackward0>)
# tensor(11.7537, grad_fn=<SumBackward0>)
# tensor(12.0400, grad_fn=<SumBackward0>)
# tensor(12.0984, grad_fn=<SumBackward0>)
# tensor(12.1318, grad_fn=<SumBackward0>)
# tensor(12.0848, grad_fn=<SumBackward0>)
# tensor(12.1249, grad_fn=<SumBackward0>)
# tensor(12.2742, grad_fn=<SumBackward0>)
# tensor(12.2530, grad_fn=<SumBackward0>)
# tensor(12.1641, grad_fn=<SumBackward0>)
# tensor(12.3922, grad_fn=<SumBackward0>)
# tensor(12.2573, grad_fn=<SumBackward0>)
# tensor(11.9222, grad_fn=<SumBackward0>)
# tensor(11.9417, grad_fn=<SumBackward0>)
# tensor(11.9404, grad_fn=<SumBackward0>)
# tensor(11.8395, grad_fn=<SumBackward0>)
# tensor(11.9095, grad_fn=<SumBackward0>)
# tensor(12.0541, grad_fn=<SumBackward0>)
# tensor(12.2658, grad_fn=<SumBackward0>)
# tensor(12.0860, grad_fn=<SumBackward0>)
# tensor(12.3622, grad_fn=<SumBackward0>)
# tensor(12.1896, grad_fn=<SumBackward0>)
# tensor(12.0294, grad_fn=<SumBackward0>)
# tensor(12.0407, grad_fn=<SumBackward0>)
# tensor(12.1976, grad_fn=<SumBackward0>)
# tensor(12.5047, grad_fn=<SumBackward0>)
# tensor(12.2987, grad_fn=<SumBackward0>)
# tensor(12.1244, grad_fn=<SumBackward0>)
# tensor(12.7711, grad_fn=<SumBackward0>)
# tensor(12.4123, grad_fn=<SumBackward0>)
# tensor(12.1955, grad_fn=<SumBackward0>)
# tensor(12.3975, grad_fn=<SumBackward0>)
# tensor(12.3248, grad_fn=<SumBackward0>)
# tensor(12.2362, grad_fn=<SumBackward0>)
# tensor(12.2608, grad_fn=<SumBackward0>)
# tensor(12.3156, grad_fn=<SumBackward0>)
# tensor(12.3265, grad_fn=<SumBackward0>)
# tensor(12.5485, grad_fn=<SumBackward0>)
# tensor(12.2224, grad_fn=<SumBackward0>)
# tensor(12.2222, grad_fn=<SumBackward0>)
# tensor(12.2491, grad_fn=<SumBackward0>)
# tensor(12.1444, grad_fn=<SumBackward0>)
# tensor(12.4321, grad_fn=<SumBackward0>)
# tensor(12.1707, grad_fn=<SumBackward0>)
# tensor(12.3226, grad_fn=<SumBackward0>)
# tensor(12.1266, grad_fn=<SumBackward0>)
# tensor(12.2634, grad_fn=<SumBackward0>)
# tensor(12.4066, grad_fn=<SumBackward0>)
# tensor(12.4434, grad_fn=<SumBackward0>)
# tensor(12.3204, grad_fn=<SumBackward0>)
# tensor(12.3963, grad_fn=<SumBackward0>)
# tensor(12.4886, grad_fn=<SumBackward0>)
# tensor(12.3736, grad_fn=<SumBackward0>)
# tensor(12.2598, grad_fn=<SumBackward0>)
# tensor(12.4342, grad_fn=<SumBackward0>)
# tensor(12.3199, grad_fn=<SumBackward0>)
# tensor(12.2285, grad_fn=<SumBackward0>)
# tensor(12.1071, grad_fn=<SumBackward0>)
# tensor(12.0886, grad_fn=<SumBackward0>)
# tensor(11.9354, grad_fn=<SumBackward0>)
# tensor(12.0917, grad_fn=<SumBackward0>)
# tensor(12.1003, grad_fn=<SumBackward0>)
# tensor(11.8301, grad_fn=<SumBackward0>)
# tensor(11.9107, grad_fn=<SumBackward0>)
# tensor(12.3072, grad_fn=<SumBackward0>)
# tensor(11.9575, grad_fn=<SumBackward0>)
# tensor(12.2860, grad_fn=<SumBackward0>)
# tensor(12.3299, grad_fn=<SumBackward0>)
# tensor(12.4474, grad_fn=<SumBackward0>)
# ...
# tensor(5.4862, grad_fn=<SumBackward0>)
# tensor(5.4828, grad_fn=<SumBackward0>)
# tensor(5.4226, grad_fn=<SumBackward0>)
# tensor(5.0317, grad_fn=<SumBackward0>)
# tensor(5.0807, grad_fn=<SumBackward0>)
# tensor(5.9461, grad_fn=<SumBackward0>)
# tensor(6.0043, grad_fn=<SumBackward0>)
# tensor(6.9954, grad_fn=<SumBackward0>)
# tensor(6.7866, grad_fn=<SumBackward0>)
# tensor(5.8466, grad_fn=<SumBackward0>)
# tensor(6.7391, grad_fn=<SumBackward0>)
# tensor(6.3627, grad_fn=<SumBackward0>)
# tensor(6.4471, grad_fn=<SumBackward0>)
# tensor(6.7482, grad_fn=<SumBackward0>)
# tensor(5.3678, grad_fn=<SumBackward0>)
# tensor(6.2479, grad_fn=<SumBackward0>)
# tensor(6.1740, grad_fn=<SumBackward0>)
# tensor(5.7509, grad_fn=<SumBackward0>)
# tensor(5.2626, grad_fn=<SumBackward0>)
# tensor(6.2204, grad_fn=<SumBackward0>)
# tensor(7.2838, grad_fn=<SumBackward0>)
# tensor(7.4047, grad_fn=<SumBackward0>)
# tensor(5.6747, grad_fn=<SumBackward0>)
# tensor(6.3020, grad_fn=<SumBackward0>)
# tensor(9.6796, grad_fn=<SumBackward0>)
# tensor(7.0132, grad_fn=<SumBackward0>)
# tensor(6.6169, grad_fn=<SumBackward0>)
# tensor(6.6358, grad_fn=<SumBackward0>)
# tensor(5.6808, grad_fn=<SumBackward0>)
# tensor(5.8180, grad_fn=<SumBackward0>)
# tensor(6.8395, grad_fn=<SumBackward0>)
# tensor(6.6504, grad_fn=<SumBackward0>)
# tensor(6.1071, grad_fn=<SumBackward0>)
# tensor(5.9166, grad_fn=<SumBackward0>)
# tensor(6.0151, grad_fn=<SumBackward0>)
# tensor(7.8021, grad_fn=<SumBackward0>)
# tensor(6.6495, grad_fn=<SumBackward0>)
# tensor(7.8847, grad_fn=<SumBackward0>)
# tensor(7.0811, grad_fn=<SumBackward0>)
# tensor(6.4063, grad_fn=<SumBackward0>)
# tensor(7.0027, grad_fn=<SumBackward0>)
# tensor(7.0054, grad_fn=<SumBackward0>)
# tensor(7.6558, grad_fn=<SumBackward0>)
# tensor(6.7963, grad_fn=<SumBackward0>)
# tensor(6.9288, grad_fn=<SumBackward0>)
# tensor(6.8842, grad_fn=<SumBackward0>)
# tensor(7.2766, grad_fn=<SumBackward0>)
# tensor(7.3009, grad_fn=<SumBackward0>)
# tensor(7.7281, grad_fn=<SumBackward0>)
# tensor(8.5811, grad_fn=<SumBackward0>)
# tensor(7.9789, grad_fn=<SumBackward0>)
# tensor(7.7711, grad_fn=<SumBackward0>)
# tensor(7.5633, grad_fn=<SumBackward0>)
# tensor(7.5375, grad_fn=<SumBackward0>)
# tensor(7.3661, grad_fn=<SumBackward0>)
# tensor(7.4879, grad_fn=<SumBackward0>)
# tensor(7.7955, grad_fn=<SumBackward0>)
# tensor(8.7068, grad_fn=<SumBackward0>)
# tensor(8.8303, grad_fn=<SumBackward0>)
# tensor(8.8181, grad_fn=<SumBackward0>)
# tensor(9.0220, grad_fn=<SumBackward0>)
# tensor(8.0705, grad_fn=<SumBackward0>)
# tensor(7.1331, grad_fn=<SumBackward0>)
# tensor(7.2878, grad_fn=<SumBackward0>)
# tensor(7.3052, grad_fn=<SumBackward0>)
# tensor(7.2743, grad_fn=<SumBackward0>)
# tensor(7.3133, grad_fn=<SumBackward0>)
# tensor(7.3738, grad_fn=<SumBackward0>)
# tensor(7.3584, grad_fn=<SumBackward0>)
# tensor(8.2868, grad_fn=<SumBackward0>)
# tensor(6.9750, grad_fn=<SumBackward0>)
# tensor(6.8346, grad_fn=<SumBackward0>)
# tensor(6.8708, grad_fn=<SumBackward0>)
# tensor(7.0510, grad_fn=<SumBackward0>)
# tensor(6.6444, grad_fn=<SumBackward0>)
# tensor(6.5648, grad_fn=<SumBackward0>)
# tensor(6.9216, grad_fn=<SumBackward0>)
# tensor(6.4078, grad_fn=<SumBackward0>)
# tensor(6.0507, grad_fn=<SumBackward0>)
# tensor(6.1080, grad_fn=<SumBackward0>)
# tensor(6.1081, grad_fn=<SumBackward0>)
# tensor(6.0541, grad_fn=<SumBackward0>)
# tensor(5.8972, grad_fn=<SumBackward0>)
# tensor(5.8915, grad_fn=<SumBackward0>)
# tensor(6.3431, grad_fn=<SumBackward0>)
# tensor(6.6303, grad_fn=<SumBackward0>)
# tensor(5.6633, grad_fn=<SumBackward0>)
# tensor(6.0975, grad_fn=<SumBackward0>)
# tensor(6.2274, grad_fn=<SumBackward0>)
# tensor(5.8781, grad_fn=<SumBackward0>)
# tensor(5.8455, grad_fn=<SumBackward0>)
# tensor(5.8448, grad_fn=<SumBackward0>)
# tensor(5.6496, grad_fn=<SumBackward0>)
# tensor(4.8569, grad_fn=<SumBackward0>)
# tensor(5.2057, grad_fn=<SumBackward0>)
# tensor(4.8183, grad_fn=<SumBackward0>)
# tensor(4.8642, grad_fn=<SumBackward0>)
# tensor(4.8203, grad_fn=<SumBackward0>)
# tensor(4.8774, grad_fn=<SumBackward0>)
# tensor(4.9699, grad_fn=<SumBackward0>)
# tensor(5.0376, grad_fn=<SumBackward0>)
# tensor(5.2680, grad_fn=<SumBackward0>)
# tensor(5.4165, grad_fn=<SumBackward0>)
# tensor(5.3719, grad_fn=<SumBackward0>)
# tensor(5.1213, grad_fn=<SumBackward0>)
# tensor(5.0274, grad_fn=<SumBackward0>)
# tensor(5.0611, grad_fn=<SumBackward0>)
# tensor(5.2893, grad_fn=<SumBackward0>)
# tensor(6.1342, grad_fn=<SumBackward0>)
# tensor(5.3548, grad_fn=<SumBackward0>)
# tensor(5.3549, grad_fn=<SumBackward0>)
# tensor(5.2615, grad_fn=<SumBackward0>)
# tensor(5.6595, grad_fn=<SumBackward0>)
# tensor(5.6468, grad_fn=<SumBackward0>)
# tensor(5.6387, grad_fn=<SumBackward0>)
# tensor(5.6905, grad_fn=<SumBackward0>)
# tensor(6.2815, grad_fn=<SumBackward0>)
# tensor(6.2141, grad_fn=<SumBackward0>)
# tensor(5.4381, grad_fn=<SumBackward0>)
# tensor(5.4379, grad_fn=<SumBackward0>)
# tensor(5.4653, grad_fn=<SumBackward0>)
# tensor(5.2522, grad_fn=<SumBackward0>)
# tensor(5.2394, grad_fn=<SumBackward0>)
# tensor(5.1910, grad_fn=<SumBackward0>)
# tensor(6.1497, grad_fn=<SumBackward0>)
# tensor(7.0224, grad_fn=<SumBackward0>)
# tensor(6.0077, grad_fn=<SumBackward0>)
# tensor(5.8008, grad_fn=<SumBackward0>)
# tensor(6.1592, grad_fn=<SumBackward0>)
# tensor(6.4216, grad_fn=<SumBackward0>)
# tensor(6.1502, grad_fn=<SumBackward0>)
# tensor(6.0685, grad_fn=<SumBackward0>)
# tensor(6.4477, grad_fn=<SumBackward0>)
# tensor(6.5381, grad_fn=<SumBackward0>)
# tensor(8.3825, grad_fn=<SumBackward0>)
# tensor(8.3815, grad_fn=<SumBackward0>)
# tensor(7.5630, grad_fn=<SumBackward0>)
# tensor(6.4222, grad_fn=<SumBackward0>)
# tensor(5.9535, grad_fn=<SumBackward0>)
# tensor(5.9671, grad_fn=<SumBackward0>)
# tensor(6.0787, grad_fn=<SumBackward0>)
# tensor(5.9244, grad_fn=<SumBackward0>)
# tensor(6.0764, grad_fn=<SumBackward0>)
# tensor(6.0939, grad_fn=<SumBackward0>)
# tensor(6.1061, grad_fn=<SumBackward0>)
# tensor(6.4318, grad_fn=<SumBackward0>)
# tensor(6.6304, grad_fn=<SumBackward0>)
# tensor(6.8606, grad_fn=<SumBackward0>)
# tensor(6.8176, grad_fn=<SumBackward0>)
# tensor(6.9764, grad_fn=<SumBackward0>)
# tensor(7.1504, grad_fn=<SumBackward0>)
# tensor(7.6935, grad_fn=<SumBackward0>)
# tensor(6.8707, grad_fn=<SumBackward0>)
# tensor(6.7830, grad_fn=<SumBackward0>)
# tensor(6.5033, grad_fn=<SumBackward0>)
# tensor(6.1121, grad_fn=<SumBackward0>)
# tensor(6.3467, grad_fn=<SumBackward0>)
# tensor(6.3113, grad_fn=<SumBackward0>)
# tensor(6.1867, grad_fn=<SumBackward0>)
# tensor(6.3839, grad_fn=<SumBackward0>)
# tensor(6.9237, grad_fn=<SumBackward0>)
# tensor(7.8578, grad_fn=<SumBackward0>)
# tensor(8.0830, grad_fn=<SumBackward0>)
# tensor(7.8400, grad_fn=<SumBackward0>)
# tensor(7.2638, grad_fn=<SumBackward0>)
# tensor(7.0369, grad_fn=<SumBackward0>)
# tensor(7.1307, grad_fn=<SumBackward0>)
# tensor(7.1519, grad_fn=<SumBackward0>)
# tensor(7.4506, grad_fn=<SumBackward0>)
# tensor(7.2753, grad_fn=<SumBackward0>)
# tensor(6.7878, grad_fn=<SumBackward0>)
# tensor(6.7509, grad_fn=<SumBackward0>)
# tensor(7.2581, grad_fn=<SumBackward0>)
# tensor(6.6901, grad_fn=<SumBackward0>)
# tensor(6.6672, grad_fn=<SumBackward0>)
# tensor(6.4104, grad_fn=<SumBackward0>)
# tensor(6.2091, grad_fn=<SumBackward0>)
# tensor(5.8576, grad_fn=<SumBackward0>)
# tensor(6.0380, grad_fn=<SumBackward0>)
# tensor(6.2181, grad_fn=<SumBackward0>)
# tensor(6.2276, grad_fn=<SumBackward0>)
# tensor(6.1282, grad_fn=<SumBackward0>)
# tensor(6.1838, grad_fn=<SumBackward0>)
# tensor(5.9388, grad_fn=<SumBackward0>)
# tensor(6.0729, grad_fn=<SumBackward0>)
# tensor(5.9966, grad_fn=<SumBackward0>)
# tensor(6.1590, grad_fn=<SumBackward0>)
# tensor(6.0199, grad_fn=<SumBackward0>)
# tensor(5.6685, grad_fn=<SumBackward0>)
# tensor(5.4289, grad_fn=<SumBackward0>)
# tensor(5.6002, grad_fn=<SumBackward0>)
# tensor(6.4217, grad_fn=<SumBackward0>)
# tensor(5.6842, grad_fn=<SumBackward0>)
# tensor(5.6141, grad_fn=<SumBackward0>)
# tensor(5.0638, grad_fn=<SumBackward0>)
# tensor(6.0689, grad_fn=<SumBackward0>)
# tensor(5.5994, grad_fn=<SumBackward0>)
# tensor(5.7269, grad_fn=<SumBackward0>)
# tensor(6.3251, grad_fn=<SumBackward0>)
# tensor(6.3033, grad_fn=<SumBackward0>)
# tensor(6.3497, grad_fn=<SumBackward0>)
# tensor(6.3025, grad_fn=<SumBackward0>)
# tensor(6.1011, grad_fn=<SumBackward0>)
# tensor(5.9000, grad_fn=<SumBackward0>)
# tensor(5.8675, grad_fn=<SumBackward0>)
# tensor(5.6689, grad_fn=<SumBackward0>)
# tensor(5.2819, grad_fn=<SumBackward0>)
# tensor(5.8621, grad_fn=<SumBackward0>)
# tensor(5.3828, grad_fn=<SumBackward0>)
# tensor(5.1281, grad_fn=<SumBackward0>)
# tensor(5.0637, grad_fn=<SumBackward0>)
# tensor(5.2708, grad_fn=<SumBackward0>)
# tensor(5.0997, grad_fn=<SumBackward0>)
# tensor(5.0345, grad_fn=<SumBackward0>)
# tensor(5.4351, grad_fn=<SumBackward0>)
# tensor(5.1648, grad_fn=<SumBackward0>)
# tensor(5.6835, grad_fn=<SumBackward0>)
# tensor(4.8986, grad_fn=<SumBackward0>)
# tensor(4.9362, grad_fn=<SumBackward0>)
# tensor(4.9033, grad_fn=<SumBackward0>)
# tensor(4.7801, grad_fn=<SumBackward0>)
# tensor(4.7801, grad_fn=<SumBackward0>)
# tensor(4.6667, grad_fn=<SumBackward0>)
# tensor(4.7432, grad_fn=<SumBackward0>)
# tensor(5.3488, grad_fn=<SumBackward0>)
# tensor(4.8898, grad_fn=<SumBackward0>)
# tensor(5.7106, grad_fn=<SumBackward0>)
# tensor(5.1595, grad_fn=<SumBackward0>)
# tensor(5.8213, grad_fn=<SumBackward0>)
# tensor(5.1010, grad_fn=<SumBackward0>)
# tensor(5.1387, grad_fn=<SumBackward0>)
# tensor(5.1244, grad_fn=<SumBackward0>)
# tensor(4.9970, grad_fn=<SumBackward0>)
# tensor(5.0099, grad_fn=<SumBackward0>)
# tensor(4.9441, grad_fn=<SumBackward0>)
# tensor(5.0128, grad_fn=<SumBackward0>)
# tensor(5.4413, grad_fn=<SumBackward0>)
# tensor(5.3844, grad_fn=<SumBackward0>)
# tensor(5.3297, grad_fn=<SumBackward0>)
# tensor(5.9585, grad_fn=<SumBackward0>)
# tensor(4.9005, grad_fn=<SumBackward0>)
# tensor(4.8001, grad_fn=<SumBackward0>)
# tensor(5.1253, grad_fn=<SumBackward0>)
# tensor(4.4830, grad_fn=<SumBackward0>)
# tensor(4.7459, grad_fn=<SumBackward0>)
# tensor(4.9847, grad_fn=<SumBackward0>)
# tensor(4.7090, grad_fn=<SumBackward0>)
# tensor(4.7422, grad_fn=<SumBackward0>)
# tensor(5.8668, grad_fn=<SumBackward0>)
# tensor(5.2367, grad_fn=<SumBackward0>)
# tensor(5.7918, grad_fn=<SumBackward0>)
# tensor(5.7309, grad_fn=<SumBackward0>)
# tensor(5.6216, grad_fn=<SumBackward0>)
# tensor(5.5442, grad_fn=<SumBackward0>)
# tensor(5.2297, grad_fn=<SumBackward0>)
# tensor(4.8249, grad_fn=<SumBackward0>)
# tensor(5.4324, grad_fn=<SumBackward0>)
# tensor(5.4801, grad_fn=<SumBackward0>)
# tensor(5.7600, grad_fn=<SumBackward0>)
# tensor(7.0809, grad_fn=<SumBackward0>)
# tensor(4.7254, grad_fn=<SumBackward0>)
# tensor(5.4259, grad_fn=<SumBackward0>)
# tensor(5.1505, grad_fn=<SumBackward0>)
# tensor(5.0174, grad_fn=<SumBackward0>)
# tensor(4.8081, grad_fn=<SumBackward0>)
# tensor(4.8183, grad_fn=<SumBackward0>)
# tensor(4.7969, grad_fn=<SumBackward0>)
# tensor(5.1084, grad_fn=<SumBackward0>)
# tensor(5.4222, grad_fn=<SumBackward0>)
# tensor(4.8562, grad_fn=<SumBackward0>)
# tensor(4.7612, grad_fn=<SumBackward0>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\fredr\Documents\cambridge\Part II Project\knowledge-distillation-transformers\notebooks\quant_test.ipynb Cell 8 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/fredr/Documents/cambridge/Part%20II%20Project/knowledge-distillation-transformers/notebooks/quant_test.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> for i in range(100000):
#       <a href='vscode-notebook-cell:/c%3A/Users/fredr/Documents/cambridge/Part%20II%20Project/knowledge-distillation-transformers/notebooks/quant_test.ipynb#W2sZmlsZQ%3D%3D?line=3'>4</a>     optimizer.zero_grad()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/fredr/Documents/cambridge/Part%20II%20Project/knowledge-distillation-transformers/notebooks/quant_test.ipynb#W2sZmlsZQ%3D%3D?line=4'>5</a>     loss = torch.sum((model(inp.float())[:,0] - (ans))**2)
#       <a href='vscode-notebook-cell:/c%3A/Users/fredr/Documents/cambridge/Part%20II%20Project/knowledge-distillation-transformers/notebooks/quant_test.ipynb#W2sZmlsZQ%3D%3D?line=5'>6</a>     loss.backward()
#       <a href='vscode-notebook-cell:/c%3A/Users/fredr/Documents/cambridge/Part%20II%20Project/knowledge-distillation-transformers/notebooks/quant_test.ipynb#W2sZmlsZQ%3D%3D?line=6'>7</a>     optimizer.step()
#
# File c:\Python310\lib\site-packages\torch\nn\modules\module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Python310\lib\site-packages\torch\nn\modules\container.py:139, in Sequential.forward(self, input)
#     137 def forward(self, input):
#     138     for module in self:
# --> 139         input = module(input)
#     140     return input
#
# File c:\Python310\lib\site-packages\torch\nn\modules\module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# c:\Users\fredr\Documents\cambridge\Part II Project\knowledge-distillation-transformers\notebooks\quant_test.ipynb Cell 8 in QuantizedLinear.forward(self, input)
#       <a href='vscode-notebook-cell:/c%3A/Users/fredr/Documents/cambridge/Part%20II%20Project/knowledge-distillation-transformers/notebooks/quant_test.ipynb#W2sZmlsZQ%3D%3D?line=8'>9</a> def forward(self, input):
#      <a href='vscode-notebook-cell:/c%3A/Users/fredr/Documents/cambridge/Part%20II%20Project/knowledge-distillation-transformers/notebooks/quant_test.ipynb#W2sZmlsZQ%3D%3D?line=9'>10</a>     if self.quantize_input:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/fredr/Documents/cambridge/Part%20II%20Project/knowledge-distillation-transformers/notebooks/quant_test.ipynb#W2sZmlsZQ%3D%3D?line=10'>11</a>         input = self.quantizer.apply(input,(-2,-1))
#      <a href='vscode-notebook-cell:/c%3A/Users/fredr/Documents/cambridge/Part%20II%20Project/knowledge-distillation-transformers/notebooks/quant_test.ipynb#W2sZmlsZQ%3D%3D?line=11'>12</a>     quant_weight = self.quantizer.apply(self.layer.weight,(0,1))
#      <a href='vscode-notebook-cell:/c%3A/Users/fredr/Documents/cambridge/Part%20II%20Project/knowledge-distillation-transformers/notebooks/quant_test.ipynb#W2sZmlsZQ%3D%3D?line=12'>13</a>     output = nn.functional.linear(input, quant_weight, self.layer.bias)
#
# c:\Users\fredr\Documents\cambridge\Part II Project\knowledge-distillation-transformers\notebooks\quant_test.ipynb Cell 8 in min_max_quantizer.<locals>.MinMaxQuantizer.forward(ctx, w, dim)
#      <a href='vscode-notebook-cell:/c%3A/Users/fredr/Documents/cambridge/Part%20II%20Project/knowledge-distillation-transformers/notebooks/quant_test.ipynb#W2sZmlsZQ%3D%3D?line=12'>13</a> mn = mx = w
#      <a href='vscode-notebook-cell:/c%3A/Users/fredr/Documents/cambridge/Part%20II%20Project/knowledge-distillation-transformers/notebooks/quant_test.ipynb#W2sZmlsZQ%3D%3D?line=13'>14</a> for d in dim:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/fredr/Documents/cambridge/Part%20II%20Project/knowledge-distillation-transformers/notebooks/quant_test.ipynb#W2sZmlsZQ%3D%3D?line=14'>15</a>     mn = torch.min(mn,dim=d).values
#      <a href='vscode-notebook-cell:/c%3A/Users/fredr/Documents/cambridge/Part%20II%20Project/knowledge-distillation-transformers/notebooks/quant_test.ipynb#W2sZmlsZQ%3D%3D?line=15'>16</a>     mx = torch.max(mx,dim=d).values
#      <a href='vscode-notebook-cell:/c%3A/Users/fredr/Documents/cambridge/Part%20II%20Project/knowledge-distillation-transformers/notebooks/quant_test.ipynb#W2sZmlsZQ%3D%3D?line=16'>17</a>     mn = mn.unsqueeze(d)
#
# KeyboardInterrupt:

# %%
model[0].layer.weight = torch.nn.Parameter(model[0].quantizer.apply(model[0].layer.weight))
model[2].layer.weight = torch.nn.Parameter(model[2].quantizer.apply(model[2].layer.weight))
model[2].layer.weight
# Out:
# Parameter containing:
# tensor([[ 0.0000,  0.0000, -5.7003,  5.7003,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000, -5.7003]], requires_grad=True)

# %%
model(torch.tensor([[0,1]]).float())
# Out:
# tensor([[0.9991]], grad_fn=<SigmoidBackward0>)
